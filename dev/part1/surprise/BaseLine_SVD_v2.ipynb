# %%
import numpy as np
from sklearn.metrics import ndcg_score
# Out:
# 0.9640700016142874

# %%
ndcg_score(np.asarray([[1,2,3,4,5]]), np.asarray([[1,2,3,5,4]]))
# Out:
# 0.9640700016142874

# %%
ndcg_score(np.asarray([[1,2.005,3,4,5]]), np.asarray([[-5,-4,-3,-2,-1]]))
# Out:
# 0.9999999999999998

# %%
ndcg_score(np.asarray([[12,50,76,94]]), np.asarray([[1,2,3,4]]))
# Out:
# 1.0

# %%
scores = np.asarray([[.05, 1.1, 1., .5, .0]])
ndcg_score(true_relevance, scores)

# we can set k to truncate the sum; only top k answers contribute.
ndcg_score(true_relevance, scores, k=4)

# the normalization takes k into account so a perfect answer
# would still get 1.0
ndcg_score(true_relevance, true_relevance, k=4)

# now we have some ties in our prediction
scores = np.asarray([[1, 0, 0, 0, 1]])
# by default ties are averaged, so here we get the average (normalized)
# true relevance of our top predictions: (10 / 10 + 5 / 10) / 2 = .75
ndcg_score(true_relevance, scores, k=1)

# we can choose to ignore ties for faster results, but only
# if we know there aren't ties in our scores, otherwise we get
# wrong results:
ndcg_score(true_relevance,
          scores, k=1, ignore_ties=True)

# %% [markdown]
# Для первой задачи мы используем данные [Jester Online Joke Recommender System](https://goldberg.berkeley.edu/jester-data/)

# %% [markdown]
# **Описание данных**
#
# Файл `train_joke_df.csv` содержит:
# - UID - id пользователей
# - JID - id шуток, которые
# - Ratin - рейтинг шутки, который проставил пользователь
#
#
# Рейтинг имеет значение от -10.00 до 10.00. Могут встречаться значения 99.00, но это обозначает Null (нет рейтинга от пользователя).
#
# Метрика для оценки [RMSE](https://www.codecamp.ru/blog/how-to-interpret-rmse/)
#
# Минимальный RMSE: `4.2238`

# %%
#!pip install "scikit-surprise==1.1.3"

# %%
#!pip install "xlrd==2.0.1"

# %% [markdown]
# ### Import

# %%
import numpy as np
import pandas as pd
from collections import defaultdict
from surprise import Dataset, Reader, accuracy
from surprise.model_selection import GridSearchCV
from surprise.model_selection import train_test_split
from sklearn.model_selection import train_test_split as tts
from surprise.model_selection import KFold

from surprise import dump
import seaborn as sns
from surprise import SVD
np.random.seed(42)

# %% [markdown]
# ### Базовые функции для скоринга и получения рекомендаций

# %%
def get_num_user_ratings(uid):
    """ возвращает кол-во рейтингов у пользователя 
    args: 
      uid: id пользователей
    returns: 
      кол-во объектов, которые оценил пользователь
    """
    try:
        return len(trainset.ur[trainset.to_inner_uid(uid)])
    except ValueError: # пользователя не было во время обучения (новый, отправить на стартовые рекомендации)
        return 0
    
def get_num_item_ratings(iid):
    """ возвращает кол-во пользователей, которые оценили выбранный элемент 
    args:
      iid: строка с элементов рекомендации
    returns:
      кол-во пользователей, которые дали оценки по элементу
    """
    try: 
        return len(trainset.ir[trainset.to_inner_iid(iid)])
    except ValueError:
        return 0
    
# На основе Surprise FAQ построим рекомендации Топ-N
def get_top_n(predictions, n=5):
    """Определят Топ-N рекомендаций

    Args:
        predictions(list of Prediction objects): Списко рекомендаций, из алгоритма Surprise
        n(int): Кол-во топ рекомендаций

    Returns:
        Словарь пользователь - список рекомендакиций для пользователей
        [(raw item id, rating estimation), ...]
    """

    # Предикт для каждого пользователя
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Сортировка предикта (по пользователям)
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %% [markdown]
# ### Загрузка и обработка данных

# %%
df = pd.read_csv(r'..\data\recsys-in-practice\train_joke_df.csv')

df.head(5)
# Out:
#      UID  JID  Rating
# 0  18029    6   -1.26
# 1   3298   64   -4.17
# 2   3366   58    0.92
# 3  12735   92    3.69
# 4  11365   38   -6.60

# %%
# сделаем сортировку и перепишем index
df = df.sort_values(by=['UID', 'JID'])
df = df.reset_index(drop=True)

# %%
# создадим на основе набора данных
# поднабор, который требуется для библиотеки Surprise

# указываем минимальный и максимальный рейтинги
reader = Reader(rating_scale=(-10, 10))

# передаём набор, указывая последовательность колонок: user (raw) ids, item (raw) ids, ratings
# для Surprise - это обязательно
data = Dataset.load_from_df(df[['UID', 'JID', 'Rating']], reader)

# %%
trainset_data = data.build_full_trainset()

# %%
# сделаем разделение на обучающую и тестовую выборку
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# %% [markdown]
# ### Обучение модели

# %%
#param_grid = {"n_epochs": [10, 20, 50, 100, 200], "n_factors": [32, 64, 100, 128, 256, 512, 1024],'random_state':[0]}

#gs = GridSearchCV(SVD, param_grid, measures=["rmse", "mae"], cv=2,)
#gs.fit(data)
     
# результат
#print(gs.best_score["rmse"])
#print(gs.best_params["rmse"])

# %%
# обучим с лучшими параметрами
#algo = SVD(random_state=0)
#algo.fit(trainset)

# получим предикт и посмотрим метрику
#predictions = algo.test(testset)
#accuracy.rmse(predictions)

#RMSE: 4.1685

#4.168486060306104

# %%
# обучим с лучшими параметрами
algo = SVD(random_state=0, n_epochs=100, n_factors= 512)
algo.fit(trainset)

# получим предикт и посмотрим метрику
predictions = algo.test(testset)
accuracy.rmse(predictions)
# Out:
# RMSE: 4.0689
# 4.0689312503214765

# %% [markdown]
# ### Тестирование и результаты

# %%
# получаем предикт
uid = 1  # id пользователя 
iid = 1  # iв шутки

# получим предик на основе обученных данных
# -7.82 - это фактический рейтинг, но посмотрим, какой ответ будет в предикте
pred = algo.predict(uid, iid, r_ui=-7.82, verbose=True)
# Out:
# user: 1          item: 1          r_ui = -7.82   est = -7.76   {'was_impossible': False}

# %%
uid = 24983  # id пользователя 
iid = 62     # iв шутки

pred = algo.predict(uid, iid, r_ui=-0.29, verbose=True)
# Out:
# user: 24983      item: 62         r_ui = -0.29   est = 0.04   {'was_impossible': False}

# %% [markdown]
# ### Обзор рекомендаций

# %%
# построим таблицу для обзора набора рекомендаций
# посмотрим, какие элементы и в каком кол-ве рекомендуем
trainset = algo.trainset

predictions_df = pd.DataFrame(predictions, columns=['uid', 'iid', 'rui', 'est', 'details'])

predictions_df['№ кол-во пользовательских рейтингов'] = predictions_df.uid.apply(get_num_user_ratings)
predictions_df['№ кол-во рейтингов элементов'] = predictions_df.iid.apply(get_num_item_ratings)
predictions_df['error'] = abs(predictions_df.est - predictions_df.rui)

best_predictions = predictions_df.sort_values(by='error')[:10]
worst_predictions = predictions_df.sort_values(by='error')[-10:]

# %%
best_predictions.head(5)
# Out:
#           uid  iid   rui       est                    details  \
# 129018   2217   57  0.44  0.440004  {'was_impossible': False}
# 144941   1247   68  5.34  5.339994  {'was_impossible': False}
# 50345    4853   43 -3.40 -3.400122  {'was_impossible': False}
# 227326  13315   88  0.29  0.289870  {'was_impossible': False}
# 42501    1927   59  1.41  1.409845  {'was_impossible': False}
#
#         № кол-во пользовательских рейтингов  № кол-во рейтингов элементов  \
# 129018                                   63                         10208
# 144941                                   30                         16017
# 50345                                    43                         11261
# 227326                                   62                          6204
# 42501                                    48                         11579
#
#            error
# 129018  0.000004
# 144941  0.000006
# 50345   0.000122
# 227326  0.000130
# 42501   0.000155

# %%
# Предикт для всех, кого нет в выборке для обучения
testset = trainset.build_anti_testset()
predictions = algo.test(testset)

top_n = get_top_n(predictions)

# Сделаем вывод рекомендаций
a=0
for uid, user_ratings in top_n.items():
    a+=1
    print(uid, [iid for (iid, _) in user_ratings])
    
    if a==10:
        break
# Out:
# 19208 [54, 89, 45, 29, 78]
# 8671 [8, 83, 75, 15, 19]
# 6037 [76, 78, 89, 27, 36]
# 3233 [50, 36, 31, 27, 48]
# 3449 [100, 73, 98, 80, 83]
# 10032 [91, 29, 35, 76, 49]
# 5774 [89, 68, 32, 23, 47]
# 23392 [62, 35, 29, 36, 48]
# 3039 [62, 27, 53, 89, 91]
# 17395 [27, 72, 89, 85, 93]

# %% [markdown]
# ### Для отправки на тестирование

# %%
# обучим с лучшими параметрами
#algo = SVD(random_state=0)
#algo.fit(trainset_data)

# получим предикт и посмотрим метрику
#predictions = algo.test(trainset_data.build_testset())
#accuracy.rmse(predictions)

#RMSE: 0.5627

#0.5626765215970747

# %%
# обучим с лучшими параметрами
algo = SVD(random_state=0, n_epochs=100, n_factors= 512)
algo.fit(trainset_data)

# получим предикт и посмотрим метрику
predictions = algo.test(trainset_data.build_testset())
accuracy.rmse(predictions)
# Out:
# RMSE: 0.2524
# 0.25238153948056485

# %%
file_name = 'baseline_svd_tuning_all_data'
dump.dump(file_name, algo=algo)
#_, loaded_algo = dump.load(file_name)

# %%
file_name = 'baseline_svd_tuning_all_data'
_, loaded_algo = dump.load(file_name)

# %%
#algo= loaded_algo
predictions = algo.test(testset)

# %%
df_true = pd.DataFrame(testset, columns = ['UID', 'JID', 'Ratings'])
df_true
# Out:
#           UID  JID  Ratings
# 0       23488  100    -1.21
# 1        9825   21     0.68
# 2        6959   28     0.15
# 3       13758  100     9.27
# 4       19135   50     5.29
# ...       ...  ...      ...
# 289668   4521   26     6.41
# 289669  24401    2     0.97
# 289670   2334   22     3.01
# 289671  11629   35     7.72
# 289672   2158   28     1.07
#
# [289673 rows x 3 columns]

# %%
df_pred = pd.DataFrame([(x[0], x[1], x[2], x[3]) for x in predictions], columns = ['UID', 'JID', 'Ratings', 'Ratings_pred'])
df_pred
# Out:
#           UID  JID  Ratings  Ratings_pred
# 0       23488  100    -1.21     -0.829102
# 1        9825   21     0.68      1.546620
# 2        6959   28     0.15     -0.208726
# 3       13758  100     9.27      5.045077
# 4       19135   50     5.29      5.683031
# ...       ...  ...      ...           ...
# 289668   4521   26     6.41      1.756193
# 289669  24401    2     0.97     -0.243122
# 289670   2334   22     3.01      2.539018
# 289671  11629   35     7.72      3.528305
# 289672   2158   28     1.07      2.811437
#
# [289673 rows x 4 columns]

# %%
df = df_pred[df_pred['UID'] == 5]
print(ndcg_score(np.asarray([df['Ratings']]), np.asarray([df['Ratings_pred']])))
df.sort_values('Ratings')
# Out:
# 0.7320358641212116
#         UID  JID  Ratings  Ratings_pred
# 223994    5   32    -9.47      5.287992
# 241752    5   57    -8.06     -3.024026
# 177305    5   86    -0.63      2.402976
# 150980    5    9    -0.44      0.293147
# 32505     5   50    -0.05      5.923128
# 240019    5   26     1.89      5.541632
# 214539    5   40     2.48      4.263993
# 62242     5   39     4.51      5.396323
# 83764     5   66     4.56      5.330146
# 80328     5    2     4.61      3.133182
# 203589    5   63     4.71      4.528047
# 89637     5   88     4.71      3.421771
# 112815    5   95     5.73      2.208855
# 261528    5   82     5.92      2.306034
# 199213    5   12     6.84      6.063172
# 111814    5   67     7.14      0.624577
# 150475    5   33     7.28      0.061729
# 222290    5   25     7.77      3.072740

# %%
# Out:
# 1.4963730218874187

# %%
np.asarray([df['Ratings']]), np.asarray(df['Ratings_pred'])
# Out:
# (array([[-9.81,  9.13,  1.12, -7.14,  0.92, -9.81, -8.98, -9.08, -4.08,
#          -9.42,  8.3 , -7.14]]),
#  array([-9.55514715,  8.89870657,  1.04821501, -7.03717141,  0.89778716,
#         -9.75808929, -8.84859383, -8.97057988, -3.74340244, -9.17969428,
#          7.97729586, -6.95938306]))

# %%
len(predictions)
# Out:
# 289673

# %%
ttt = []
for u in range(1, 24983 + 1):
    for j in range(1, 101):
        ttt.append((u, j, 0))

# %%
pred = algo.test(ttt)

# %%
pred
# Out:
# [Prediction(uid=1, iid=1, r_ui=0, est=-7.5869082363041125, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2, r_ui=0, est=8.382193195823827, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3, r_ui=0, est=-9.501438022434291, details={'was_impossible': False}),
#  Prediction(uid=1, iid=4, r_ui=0, est=-8.181289711605473, details={'was_impossible': False}),
#  Prediction(uid=1, iid=5, r_ui=0, est=-7.368125640525279, details={'was_impossible': False}),
#  Prediction(uid=1, iid=6, r_ui=0, est=-8.202881206876636, details={'was_impossible': False}),
#  Prediction(uid=1, iid=7, r_ui=0, est=-9.65915638100404, details={'was_impossible': False}),
#  Prediction(uid=1, iid=8, r_ui=0, est=3.849424515470821, details={'was_impossible': False}),
#  Prediction(uid=1, iid=9, r_ui=0, est=-8.848593832230408, details={'was_impossible': False}),
#  Prediction(uid=1, iid=10, r_ui=0, est=-4.705652247369905, details={'was_impossible': False}),
#  Prediction(uid=1, iid=11, r_ui=0, est=-3.2292266832839562, details={'was_impossible': False}),
#  Prediction(uid=1, iid=12, r_ui=0, est=-6.409789109265508, details={'was_impossible': False}),
#  Prediction(uid=1, iid=13, r_ui=0, est=-7.024773392560044, details={'was_impossible': False}),
#  Prediction(uid=1, iid=14, r_ui=0, est=8.1204072535496, details={'was_impossible': False}),
#  Prediction(uid=1, iid=15, r_ui=0, est=-7.101641366968603, details={'was_impossible': False}),
#  Prediction(uid=1, iid=16, r_ui=0, est=-7.505614725835342, details={'was_impossible': False}),
#  Prediction(uid=1, iid=17, r_ui=0, est=-7.267275025077714, details={'was_impossible': False}),
#  Prediction(uid=1, iid=18, r_ui=0, est=-9.555147154617341, details={'was_impossible': False}),
#  Prediction(uid=1, iid=19, r_ui=0, est=-5.428870587262538, details={'was_impossible': False}),
#  Prediction(uid=1, iid=20, r_ui=0, est=-9.642741695534955, details={'was_impossible': False}),
#  Prediction(uid=1, iid=21, r_ui=0, est=-8.909191928719059, details={'was_impossible': False}),
#  Prediction(uid=1, iid=22, r_ui=0, est=1.3049553917546022, details={'was_impossible': False}),
#  Prediction(uid=1, iid=23, r_ui=0, est=-4.373984702925547, details={'was_impossible': False}),
#  Prediction(uid=1, iid=24, r_ui=0, est=-9.758089291918346, details={'was_impossible': False}),
#  Prediction(uid=1, iid=25, r_ui=0, est=-3.8801026283200417, details={'was_impossible': False}),
#  Prediction(uid=1, iid=26, r_ui=0, est=1.0482150086619777, details={'was_impossible': False}),
#  Prediction(uid=1, iid=27, r_ui=0, est=7.591823178271042, details={'was_impossible': False}),
#  Prediction(uid=1, iid=28, r_ui=0, est=2.6997348442810334, details={'was_impossible': False}),
#  Prediction(uid=1, iid=29, r_ui=0, est=8.898706568225885, details={'was_impossible': False}),
#  Prediction(uid=1, iid=30, r_ui=0, est=-7.400254999612057, details={'was_impossible': False}),
#  Prediction(uid=1, iid=31, r_ui=0, est=1.7459330866314655, details={'was_impossible': False}),
#  Prediction(uid=1, iid=32, r_ui=0, est=-3.743402438630424, details={'was_impossible': False}),
#  Prediction(uid=1, iid=33, r_ui=0, est=-8.998199372589479, details={'was_impossible': False}),
#  Prediction(uid=1, iid=34, r_ui=0, est=-2.317229228569088, details={'was_impossible': False}),
#  Prediction(uid=1, iid=35, r_ui=0, est=4.970112179440567, details={'was_impossible': False}),
#  Prediction(uid=1, iid=36, r_ui=0, est=4.86158563160358, details={'was_impossible': False}),
#  Prediction(uid=1, iid=37, r_ui=0, est=-9.048827095999183, details={'was_impossible': False}),
#  Prediction(uid=1, iid=38, r_ui=0, est=-8.141232485431471, details={'was_impossible': False}),
#  Prediction(uid=1, iid=39, r_ui=0, est=-2.854284176643082, details={'was_impossible': False}),
#  Prediction(uid=1, iid=40, r_ui=0, est=-4.666990232664525, details={'was_impossible': False}),
#  Prediction(uid=1, iid=41, r_ui=0, est=-8.04916114805949, details={'was_impossible': False}),
#  Prediction(uid=1, iid=42, r_ui=0, est=-8.728721220759008, details={'was_impossible': False}),
#  Prediction(uid=1, iid=43, r_ui=0, est=-8.935575869804282, details={'was_impossible': False}),
#  Prediction(uid=1, iid=44, r_ui=0, est=-9.032891167734999, details={'was_impossible': False}),
#  Prediction(uid=1, iid=45, r_ui=0, est=-6.9593830631555775, details={'was_impossible': False}),
#  Prediction(uid=1, iid=46, r_ui=0, est=0.10043949862813584, details={'was_impossible': False}),
#  Prediction(uid=1, iid=47, r_ui=0, est=3.630214515267255, details={'was_impossible': False}),
#  Prediction(uid=1, iid=48, r_ui=0, est=-0.06312867996442029, details={'was_impossible': False}),
#  Prediction(uid=1, iid=49, r_ui=0, est=2.080797617512883, details={'was_impossible': False}),
#  Prediction(uid=1, iid=50, r_ui=0, est=4.107928045793073, details={'was_impossible': False}),
#  Prediction(uid=1, iid=51, r_ui=0, est=-8.560118873517844, details={'was_impossible': False}),
#  Prediction(uid=1, iid=52, r_ui=0, est=-7.037171407583987, details={'was_impossible': False}),
#  Prediction(uid=1, iid=53, r_ui=0, est=3.2300444576905014, details={'was_impossible': False}),
#  Prediction(uid=1, iid=54, r_ui=0, est=8.068271189344168, details={'was_impossible': False}),
#  Prediction(uid=1, iid=55, r_ui=0, est=-4.499081039903628, details={'was_impossible': False}),
#  Prediction(uid=1, iid=56, r_ui=0, est=0.8977871589774014, details={'was_impossible': False}),
#  Prediction(uid=1, iid=57, r_ui=0, est=-9.063565574828845, details={'was_impossible': False}),
#  Prediction(uid=1, iid=58, r_ui=0, est=-9.391803416754332, details={'was_impossible': False}),
#  Prediction(uid=1, iid=59, r_ui=0, est=2.463207118025733, details={'was_impossible': False}),
#  Prediction(uid=1, iid=60, r_ui=0, est=-4.86787295539153, details={'was_impossible': False}),
#  Prediction(uid=1, iid=61, r_ui=0, est=8.281268687995368, details={'was_impossible': False}),
#  Prediction(uid=1, iid=62, r_ui=0, est=3.5087029474422775, details={'was_impossible': False}),
#  Prediction(uid=1, iid=63, r_ui=0, est=-6.682795742833007, details={'was_impossible': False}),
#  Prediction(uid=1, iid=64, r_ui=0, est=-8.87764742864266, details={'was_impossible': False}),
#  Prediction(uid=1, iid=65, r_ui=0, est=0.17232500326865785, details={'was_impossible': False}),
#  Prediction(uid=1, iid=66, r_ui=0, est=-1.2486265981571738, details={'was_impossible': False}),
#  Prediction(uid=1, iid=67, r_ui=0, est=-8.970579878637981, details={'was_impossible': False}),
#  Prediction(uid=1, iid=68, r_ui=0, est=7.977295856565026, details={'was_impossible': False}),
#  Prediction(uid=1, iid=69, r_ui=0, est=5.484545211601245, details={'was_impossible': False}),
#  Prediction(uid=1, iid=70, r_ui=0, est=-4.781364863570172, details={'was_impossible': False}),
#  Prediction(uid=1, iid=71, r_ui=0, est=-3.7206345552677247, details={'was_impossible': False}),
#  Prediction(uid=1, iid=72, r_ui=0, est=-0.11054122026192859, details={'was_impossible': False}),
#  Prediction(uid=1, iid=73, r_ui=0, est=-5.085393744635648, details={'was_impossible': False}),
#  Prediction(uid=1, iid=74, r_ui=0, est=-6.82303478925918, details={'was_impossible': False}),
#  Prediction(uid=1, iid=75, r_ui=0, est=-5.982477019911048, details={'was_impossible': False}),
#  Prediction(uid=1, iid=76, r_ui=0, est=-0.45614108974798107, details={'was_impossible': False}),
#  Prediction(uid=1, iid=77, r_ui=0, est=-4.767463075999157, details={'was_impossible': False}),
#  Prediction(uid=1, iid=78, r_ui=0, est=-9.17969428193028, details={'was_impossible': False}),
#  Prediction(uid=1, iid=79, r_ui=0, est=-5.6770538537454645, details={'was_impossible': False}),
#  Prediction(uid=1, iid=80, r_ui=0, est=-2.581810188785891, details={'was_impossible': False}),
#  Prediction(uid=1, iid=81, r_ui=0, est=-2.849942178550789, details={'was_impossible': False}),
#  Prediction(uid=1, iid=82, r_ui=0, est=-7.565451469022632, details={'was_impossible': False}),
#  Prediction(uid=1, iid=83, r_ui=0, est=-1.7117865613582528, details={'was_impossible': False}),
#  Prediction(uid=1, iid=84, r_ui=0, est=-3.7129663504355657, details={'was_impossible': False}),
#  Prediction(uid=1, iid=85, r_ui=0, est=-4.386430664395008, details={'was_impossible': False}),
#  Prediction(uid=1, iid=86, r_ui=0, est=-5.514841568078301, details={'was_impossible': False}),
#  Prediction(uid=1, iid=87, r_ui=0, est=-2.478438725330892, details={'was_impossible': False}),
#  Prediction(uid=1, iid=88, r_ui=0, est=-1.9647480309300027, details={'was_impossible': False}),
#  Prediction(uid=1, iid=89, r_ui=0, est=1.739821787808388, details={'was_impossible': False}),
#  Prediction(uid=1, iid=90, r_ui=0, est=-5.165312160452079, details={'was_impossible': False}),
#  Prediction(uid=1, iid=91, r_ui=0, est=-0.9954757330525609, details={'was_impossible': False}),
#  Prediction(uid=1, iid=92, r_ui=0, est=-2.650232453737493, details={'was_impossible': False}),
#  Prediction(uid=1, iid=93, r_ui=0, est=-0.7440896410571576, details={'was_impossible': False}),
#  Prediction(uid=1, iid=94, r_ui=0, est=-5.037513973817473, details={'was_impossible': False}),
#  Prediction(uid=1, iid=95, r_ui=0, est=-3.725242703458887, details={'was_impossible': False}),
#  Prediction(uid=1, iid=96, r_ui=0, est=-3.580553662598738, details={'was_impossible': False}),
#  Prediction(uid=1, iid=97, r_ui=0, est=-5.4905935444000775, details={'was_impossible': False}),
#  Prediction(uid=1, iid=98, r_ui=0, est=-2.405267400506938, details={'was_impossible': False}),
#  Prediction(uid=1, iid=99, r_ui=0, est=-5.027696336020645, details={'was_impossible': False}),
#  Prediction(uid=1, iid=100, r_ui=0, est=-3.0181543525420924, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1, r_ui=0, est=4.024886700182046, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2, r_ui=0, est=-0.17664066947459256, details={'was_impossible': False}),
#  Prediction(uid=2, iid=3, r_ui=0, est=6.278876443181292, details={'was_impossible': False}),
#  Prediction(uid=2, iid=4, r_ui=0, est=4.4160417729658885, details={'was_impossible': False}),
#  Prediction(uid=2, iid=5, r_ui=0, est=2.0044103517110674, details={'was_impossible': False}),
#  Prediction(uid=2, iid=6, r_ui=0, est=-9.096344597963718, details={'was_impossible': False}),
#  Prediction(uid=2, iid=7, r_ui=0, est=-0.6575387706499445, details={'was_impossible': False}),
#  Prediction(uid=2, iid=8, r_ui=0, est=-4.9535474604004115, details={'was_impossible': False}),
#  Prediction(uid=2, iid=9, r_ui=0, est=8.676071861995299, details={'was_impossible': False}),
#  Prediction(uid=2, iid=10, r_ui=0, est=9.017982248970679, details={'was_impossible': False}),
#  Prediction(uid=2, iid=11, r_ui=0, est=6.571519000160764, details={'was_impossible': False}),
#  Prediction(uid=2, iid=12, r_ui=0, est=8.171072666230906, details={'was_impossible': False}),
#  Prediction(uid=2, iid=13, r_ui=0, est=4.247550596616923, details={'was_impossible': False}),
#  Prediction(uid=2, iid=14, r_ui=0, est=-0.40111356699665945, details={'was_impossible': False}),
#  Prediction(uid=2, iid=15, r_ui=0, est=4.351286783438835, details={'was_impossible': False}),
#  Prediction(uid=2, iid=16, r_ui=0, est=-0.8228534738773698, details={'was_impossible': False}),
#  Prediction(uid=2, iid=17, r_ui=0, est=0.12467159094000857, details={'was_impossible': False}),
#  Prediction(uid=2, iid=18, r_ui=0, est=-0.6083339675221537, details={'was_impossible': False}),
#  Prediction(uid=2, iid=19, r_ui=0, est=3.1306420229208305, details={'was_impossible': False}),
#  Prediction(uid=2, iid=20, r_ui=0, est=-1.1218463056214578, details={'was_impossible': False}),
#  Prediction(uid=2, iid=21, r_ui=0, est=0.9988105100811508, details={'was_impossible': False}),
#  Prediction(uid=2, iid=22, r_ui=0, est=8.3915055148187, details={'was_impossible': False}),
#  Prediction(uid=2, iid=23, r_ui=0, est=8.118871326311213, details={'was_impossible': False}),
#  Prediction(uid=2, iid=24, r_ui=0, est=9.005382636474387, details={'was_impossible': False}),
#  Prediction(uid=2, iid=25, r_ui=0, est=0.1899419919595794, details={'was_impossible': False}),
#  Prediction(uid=2, iid=26, r_ui=0, est=7.137527663098374, details={'was_impossible': False}),
#  Prediction(uid=2, iid=27, r_ui=0, est=4.514905373229643, details={'was_impossible': False}),
#  Prediction(uid=2, iid=28, r_ui=0, est=-1.4948295967208312, details={'was_impossible': False}),
#  Prediction(uid=2, iid=29, r_ui=0, est=-0.32256301271963306, details={'was_impossible': False}),
#  Prediction(uid=2, iid=30, r_ui=0, est=4.776374642437179, details={'was_impossible': False}),
#  Prediction(uid=2, iid=31, r_ui=0, est=1.2096044752718476, details={'was_impossible': False}),
#  Prediction(uid=2, iid=32, r_ui=0, est=-0.9538510929445252, details={'was_impossible': False}),
#  Prediction(uid=2, iid=33, r_ui=0, est=6.983918523012841, details={'was_impossible': False}),
#  Prediction(uid=2, iid=34, r_ui=0, est=8.717547594739088, details={'was_impossible': False}),
#  Prediction(uid=2, iid=35, r_ui=0, est=-1.671688007416913, details={'was_impossible': False}),
#  Prediction(uid=2, iid=36, r_ui=0, est=0.7795565253479735, details={'was_impossible': False}),
#  Prediction(uid=2, iid=37, r_ui=0, est=1.5239922959653736, details={'was_impossible': False}),
#  Prediction(uid=2, iid=38, r_ui=0, est=3.346839173005801, details={'was_impossible': False}),
#  Prediction(uid=2, iid=39, r_ui=0, est=-0.7209919884846174, details={'was_impossible': False}),
#  Prediction(uid=2, iid=40, r_ui=0, est=7.653700499418478, details={'was_impossible': False}),
#  Prediction(uid=2, iid=41, r_ui=0, est=7.569382223239672, details={'was_impossible': False}),
#  Prediction(uid=2, iid=42, r_ui=0, est=-3.591305377347756, details={'was_impossible': False}),
#  Prediction(uid=2, iid=43, r_ui=0, est=8.393230343317068, details={'was_impossible': False}),
#  Prediction(uid=2, iid=44, r_ui=0, est=8.79040905045715, details={'was_impossible': False}),
#  Prediction(uid=2, iid=45, r_ui=0, est=-4.028776161435035, details={'was_impossible': False}),
#  Prediction(uid=2, iid=46, r_ui=0, est=-2.9719813318936743, details={'was_impossible': False}),
#  Prediction(uid=2, iid=47, r_ui=0, est=-4.689204495993446, details={'was_impossible': False}),
#  Prediction(uid=2, iid=48, r_ui=0, est=-0.8945076441746687, details={'was_impossible': False}),
#  Prediction(uid=2, iid=49, r_ui=0, est=-0.7805667280338704, details={'was_impossible': False}),
#  Prediction(uid=2, iid=50, r_ui=0, est=3.472520573503732, details={'was_impossible': False}),
#  Prediction(uid=2, iid=51, r_ui=0, est=3.247122342294858, details={'was_impossible': False}),
#  Prediction(uid=2, iid=52, r_ui=0, est=2.883956689004395, details={'was_impossible': False}),
#  Prediction(uid=2, iid=53, r_ui=0, est=0.9092788677583452, details={'was_impossible': False}),
#  Prediction(uid=2, iid=54, r_ui=0, est=-1.2918378811424573, details={'was_impossible': False}),
#  Prediction(uid=2, iid=55, r_ui=0, est=-5.98778308012032, details={'was_impossible': False}),
#  Prediction(uid=2, iid=56, r_ui=0, est=-3.0123506473611688, details={'was_impossible': False}),
#  Prediction(uid=2, iid=57, r_ui=0, est=8.383718641414877, details={'was_impossible': False}),
#  Prediction(uid=2, iid=58, r_ui=0, est=-1.8770497603994607, details={'was_impossible': False}),
#  Prediction(uid=2, iid=59, r_ui=0, est=0.2528881123647615, details={'was_impossible': False}),
#  Prediction(uid=2, iid=60, r_ui=0, est=8.732601221525865, details={'was_impossible': False}),
#  Prediction(uid=2, iid=61, r_ui=0, est=-6.327615996035018, details={'was_impossible': False}),
#  Prediction(uid=2, iid=62, r_ui=0, est=-3.1511629815345366, details={'was_impossible': False}),
#  Prediction(uid=2, iid=63, r_ui=0, est=-8.568183086400973, details={'was_impossible': False}),
#  Prediction(uid=2, iid=64, r_ui=0, est=4.4260889275189825, details={'was_impossible': False}),
#  Prediction(uid=2, iid=65, r_ui=0, est=3.9939412846833147, details={'was_impossible': False}),
#  Prediction(uid=2, iid=66, r_ui=0, est=-3.5863150138720363, details={'was_impossible': False}),
#  Prediction(uid=2, iid=67, r_ui=0, est=8.53623106742381, details={'was_impossible': False}),
#  Prediction(uid=2, iid=68, r_ui=0, est=1.0384001646624035, details={'was_impossible': False}),
#  Prediction(uid=2, iid=69, r_ui=0, est=0.7415353974588721, details={'was_impossible': False}),
#  Prediction(uid=2, iid=70, r_ui=0, est=7.23754231998257, details={'was_impossible': False}),
#  Prediction(uid=2, iid=71, r_ui=0, est=-4.765922758955547, details={'was_impossible': False}),
#  Prediction(uid=2, iid=72, r_ui=0, est=3.168041867659453, details={'was_impossible': False}),
#  Prediction(uid=2, iid=73, r_ui=0, est=8.142117388514057, details={'was_impossible': False}),
#  Prediction(uid=2, iid=74, r_ui=0, est=7.660990215628899, details={'was_impossible': False}),
#  Prediction(uid=2, iid=75, r_ui=0, est=3.4069960944695503, details={'was_impossible': False}),
#  Prediction(uid=2, iid=76, r_ui=0, est=6.016967659080306, details={'was_impossible': False}),
#  Prediction(uid=2, iid=77, r_ui=0, est=7.5693087006906605, details={'was_impossible': False}),
#  Prediction(uid=2, iid=78, r_ui=0, est=8.814666249581599, details={'was_impossible': False}),
#  Prediction(uid=2, iid=79, r_ui=0, est=8.445612741924567, details={'was_impossible': False}),
#  Prediction(uid=2, iid=80, r_ui=0, est=3.992264305649627, details={'was_impossible': False}),
#  Prediction(uid=2, iid=81, r_ui=0, est=3.93884150382424, details={'was_impossible': False}),
#  Prediction(uid=2, iid=82, r_ui=0, est=4.739146254037605, details={'was_impossible': False}),
#  Prediction(uid=2, iid=83, r_ui=0, est=4.794903259314504, details={'was_impossible': False}),
#  Prediction(uid=2, iid=84, r_ui=0, est=5.910625497751324, details={'was_impossible': False}),
#  Prediction(uid=2, iid=85, r_ui=0, est=8.764587169323514, details={'was_impossible': False}),
#  Prediction(uid=2, iid=86, r_ui=0, est=4.541757408566554, details={'was_impossible': False}),
#  Prediction(uid=2, iid=87, r_ui=0, est=0.07475273478133104, details={'was_impossible': False}),
#  Prediction(uid=2, iid=88, r_ui=0, est=3.5976884057588947, details={'was_impossible': False}),
#  Prediction(uid=2, iid=89, r_ui=0, est=1.505097370992003, details={'was_impossible': False}),
#  Prediction(uid=2, iid=90, r_ui=0, est=0.6325964067881613, details={'was_impossible': False}),
#  Prediction(uid=2, iid=91, r_ui=0, est=2.7844584311952176, details={'was_impossible': False}),
#  Prediction(uid=2, iid=92, r_ui=0, est=-4.678753245651895, details={'was_impossible': False}),
#  Prediction(uid=2, iid=93, r_ui=0, est=-0.2113287334615439, details={'was_impossible': False}),
#  Prediction(uid=2, iid=94, r_ui=0, est=7.64676340459704, details={'was_impossible': False}),
#  Prediction(uid=2, iid=95, r_ui=0, est=-0.09957895186607724, details={'was_impossible': False}),
#  Prediction(uid=2, iid=96, r_ui=0, est=1.6167997192570729, details={'was_impossible': False}),
#  Prediction(uid=2, iid=97, r_ui=0, est=2.959577707911966, details={'was_impossible': False}),
#  Prediction(uid=2, iid=98, r_ui=0, est=3.0322828267421813, details={'was_impossible': False}),
#  Prediction(uid=2, iid=99, r_ui=0, est=-4.0531237095019765, details={'was_impossible': False}),
#  Prediction(uid=2, iid=100, r_ui=0, est=4.093076948260026, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1, r_ui=0, est=7.101710995714059, details={'was_impossible': False}),
#  Prediction(uid=3, iid=2, r_ui=0, est=7.459340085618992, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3, r_ui=0, est=6.072468584453707, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4, r_ui=0, est=4.810042609214662, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5, r_ui=0, est=8.921578152423018, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6, r_ui=0, est=9.184495606791668, details={'was_impossible': False}),
#  Prediction(uid=3, iid=7, r_ui=0, est=8.911569285135744, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8, r_ui=0, est=9.072566434706822, details={'was_impossible': False}),
#  Prediction(uid=3, iid=9, r_ui=0, est=6.243429951469147, details={'was_impossible': False}),
#  Prediction(uid=3, iid=10, r_ui=0, est=7.018425142265546, details={'was_impossible': False}),
#  Prediction(uid=3, iid=11, r_ui=0, est=7.310558893567894, details={'was_impossible': False}),
#  Prediction(uid=3, iid=12, r_ui=0, est=7.5406043300797805, details={'was_impossible': False}),
#  Prediction(uid=3, iid=13, r_ui=0, est=9.165720480455123, details={'was_impossible': False}),
#  Prediction(uid=3, iid=14, r_ui=0, est=5.626662054958425, details={'was_impossible': False}),
#  Prediction(uid=3, iid=15, r_ui=0, est=-6.148698967349077, details={'was_impossible': False}),
#  Prediction(uid=3, iid=16, r_ui=0, est=-6.655568544315809, details={'was_impossible': False}),
#  Prediction(uid=3, iid=17, r_ui=0, est=-7.5104717323128245, details={'was_impossible': False}),
#  Prediction(uid=3, iid=18, r_ui=0, est=8.880456517416027, details={'was_impossible': False}),
#  Prediction(uid=3, iid=19, r_ui=0, est=8.931784011305577, details={'was_impossible': False}),
#  Prediction(uid=3, iid=20, r_ui=0, est=8.935174988638169, details={'was_impossible': False}),
#  Prediction(uid=3, iid=21, r_ui=0, est=7.226736896023992, details={'was_impossible': False}),
#  Prediction(uid=3, iid=22, r_ui=0, est=6.026023042849966, details={'was_impossible': False}),
#  Prediction(uid=3, iid=23, r_ui=0, est=8.181043383408323, details={'was_impossible': False}),
#  Prediction(uid=3, iid=24, r_ui=0, est=4.390729145160119, details={'was_impossible': False}),
#  Prediction(uid=3, iid=25, r_ui=0, est=6.1227760997152, details={'was_impossible': False}),
#  Prediction(uid=3, iid=26, r_ui=0, est=7.438339883936504, details={'was_impossible': False}),
#  Prediction(uid=3, iid=27, r_ui=0, est=6.69921579081924, details={'was_impossible': False}),
#  Prediction(uid=3, iid=28, r_ui=0, est=7.27564463300317, details={'was_impossible': False}),
#  Prediction(uid=3, iid=29, r_ui=0, est=8.85022979953195, details={'was_impossible': False}),
#  Prediction(uid=3, iid=30, r_ui=0, est=7.096536708674006, details={'was_impossible': False}),
#  Prediction(uid=3, iid=31, r_ui=0, est=6.179563632434471, details={'was_impossible': False}),
#  Prediction(uid=3, iid=32, r_ui=0, est=7.251845260097696, details={'was_impossible': False}),
#  Prediction(uid=3, iid=33, r_ui=0, est=4.88625589751544, details={'was_impossible': False}),
#  Prediction(uid=3, iid=34, r_ui=0, est=6.143248062149491, details={'was_impossible': False}),
#  Prediction(uid=3, iid=35, r_ui=0, est=8.91008061774752, details={'was_impossible': False}),
#  Prediction(uid=3, iid=36, r_ui=0, est=7.306282392068958, details={'was_impossible': False}),
#  Prediction(uid=3, iid=37, r_ui=0, est=4.202166301802694, details={'was_impossible': False}),
#  Prediction(uid=3, iid=38, r_ui=0, est=7.021061992068314, details={'was_impossible': False}),
#  Prediction(uid=3, iid=39, r_ui=0, est=8.977229716829209, details={'was_impossible': False}),
#  Prediction(uid=3, iid=40, r_ui=0, est=7.319179531658957, details={'was_impossible': False}),
#  Prediction(uid=3, iid=41, r_ui=0, est=6.20947084279584, details={'was_impossible': False}),
#  Prediction(uid=3, iid=42, r_ui=0, est=5.734014289718574, details={'was_impossible': False}),
#  Prediction(uid=3, iid=43, r_ui=0, est=9.163868653604524, details={'was_impossible': False}),
#  Prediction(uid=3, iid=44, r_ui=0, est=3.155827629639929, details={'was_impossible': False}),
#  Prediction(uid=3, iid=45, r_ui=0, est=9.178774410135725, details={'was_impossible': False}),
#  Prediction(uid=3, iid=46, r_ui=0, est=5.784216651034852, details={'was_impossible': False}),
#  Prediction(uid=3, iid=47, r_ui=0, est=7.040688248136853, details={'was_impossible': False}),
#  Prediction(uid=3, iid=48, r_ui=0, est=7.322784406862162, details={'was_impossible': False}),
#  Prediction(uid=3, iid=49, r_ui=0, est=8.99549739942989, details={'was_impossible': False}),
#  Prediction(uid=3, iid=50, r_ui=0, est=7.227486752605326, details={'was_impossible': False}),
#  Prediction(uid=3, iid=51, r_ui=0, est=6.325817073108149, details={'was_impossible': False}),
#  Prediction(uid=3, iid=52, r_ui=0, est=6.856241939231264, details={'was_impossible': False}),
#  Prediction(uid=3, iid=53, r_ui=0, est=6.550181902223925, details={'was_impossible': False}),
#  Prediction(uid=3, iid=54, r_ui=0, est=7.300344621859304, details={'was_impossible': False}),
#  Prediction(uid=3, iid=55, r_ui=0, est=5.824212649907868, details={'was_impossible': False}),
#  Prediction(uid=3, iid=56, r_ui=0, est=7.207613725194937, details={'was_impossible': False}),
#  Prediction(uid=3, iid=57, r_ui=0, est=3.6351157304850013, details={'was_impossible': False}),
#  Prediction(uid=3, iid=58, r_ui=0, est=1.2506331063150031, details={'was_impossible': False}),
#  Prediction(uid=3, iid=59, r_ui=0, est=6.812244344773344, details={'was_impossible': False}),
#  Prediction(uid=3, iid=60, r_ui=0, est=9.166494574496786, details={'was_impossible': False}),
#  Prediction(uid=3, iid=61, r_ui=0, est=6.492027064355773, details={'was_impossible': False}),
#  Prediction(uid=3, iid=62, r_ui=0, est=7.263976727902056, details={'was_impossible': False}),
#  Prediction(uid=3, iid=63, r_ui=0, est=6.752916439879387, details={'was_impossible': False}),
#  Prediction(uid=3, iid=64, r_ui=0, est=5.492803371400495, details={'was_impossible': False}),
#  Prediction(uid=3, iid=65, r_ui=0, est=6.9952724565846705, details={'was_impossible': False}),
#  Prediction(uid=3, iid=66, r_ui=0, est=7.252320594209255, details={'was_impossible': False}),
#  Prediction(uid=3, iid=67, r_ui=0, est=5.070297245647854, details={'was_impossible': False}),
#  Prediction(uid=3, iid=68, r_ui=0, est=7.267714579594539, details={'was_impossible': False}),
#  Prediction(uid=3, iid=69, r_ui=0, est=8.18272523428572, details={'was_impossible': False}),
#  Prediction(uid=3, iid=70, r_ui=0, est=6.749648761522233, details={'was_impossible': False}),
#  Prediction(uid=3, iid=71, r_ui=0, est=4.757960420574045, details={'was_impossible': False}),
#  Prediction(uid=3, iid=72, r_ui=0, est=6.353131270862132, details={'was_impossible': False}),
#  Prediction(uid=3, iid=73, r_ui=0, est=6.063141086353463, details={'was_impossible': False}),
#  Prediction(uid=3, iid=74, r_ui=0, est=3.439892800974782, details={'was_impossible': False}),
#  Prediction(uid=3, iid=75, r_ui=0, est=2.297901996179618, details={'was_impossible': False}),
#  Prediction(uid=3, iid=76, r_ui=0, est=8.846687482742231, details={'was_impossible': False}),
#  Prediction(uid=3, iid=77, r_ui=0, est=5.089303419111082, details={'was_impossible': False}),
#  Prediction(uid=3, iid=78, r_ui=0, est=6.628152123130972, details={'was_impossible': False}),
#  Prediction(uid=3, iid=79, r_ui=0, est=5.279511456175012, details={'was_impossible': False}),
#  Prediction(uid=3, iid=80, r_ui=0, est=8.995329423012862, details={'was_impossible': False}),
#  Prediction(uid=3, iid=81, r_ui=0, est=5.395189166161931, details={'was_impossible': False}),
#  Prediction(uid=3, iid=82, r_ui=0, est=4.956506668233251, details={'was_impossible': False}),
#  Prediction(uid=3, iid=83, r_ui=0, est=5.664002321015236, details={'was_impossible': False}),
#  Prediction(uid=3, iid=84, r_ui=0, est=6.144327272223867, details={'was_impossible': False}),
#  Prediction(uid=3, iid=85, r_ui=0, est=5.176120845821309, details={'was_impossible': False}),
#  Prediction(uid=3, iid=86, r_ui=0, est=3.9118418243853093, details={'was_impossible': False}),
#  Prediction(uid=3, iid=87, r_ui=0, est=5.341837230955772, details={'was_impossible': False}),
#  Prediction(uid=3, iid=88, r_ui=0, est=6.364440224742172, details={'was_impossible': False}),
#  Prediction(uid=3, iid=89, r_ui=0, est=7.62032647818097, details={'was_impossible': False}),
#  Prediction(uid=3, iid=90, r_ui=0, est=8.94500392503897, details={'was_impossible': False}),
#  Prediction(uid=3, iid=91, r_ui=0, est=4.649412566742935, details={'was_impossible': False}),
#  Prediction(uid=3, iid=92, r_ui=0, est=5.480579215469087, details={'was_impossible': False}),
#  Prediction(uid=3, iid=93, r_ui=0, est=6.9897949070441125, details={'was_impossible': False}),
#  Prediction(uid=3, iid=94, r_ui=0, est=4.565457892024957, details={'was_impossible': False}),
#  Prediction(uid=3, iid=95, r_ui=0, est=5.601910459339726, details={'was_impossible': False}),
#  Prediction(uid=3, iid=96, r_ui=0, est=5.698606209470789, details={'was_impossible': False}),
#  Prediction(uid=3, iid=97, r_ui=0, est=5.816308222760333, details={'was_impossible': False}),
#  Prediction(uid=3, iid=98, r_ui=0, est=4.933325032315534, details={'was_impossible': False}),
#  Prediction(uid=3, iid=99, r_ui=0, est=4.751782240098902, details={'was_impossible': False}),
#  Prediction(uid=3, iid=100, r_ui=0, est=5.787020359874561, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1, r_ui=0, est=2.9693091765865383, details={'was_impossible': False}),
#  Prediction(uid=4, iid=2, r_ui=0, est=8.206091015983711, details={'was_impossible': False}),
#  Prediction(uid=4, iid=3, r_ui=0, est=2.796239109296897, details={'was_impossible': False}),
#  Prediction(uid=4, iid=4, r_ui=0, est=2.0808353945247253, details={'was_impossible': False}),
#  Prediction(uid=4, iid=5, r_ui=0, est=1.8055329971701974, details={'was_impossible': False}),
#  Prediction(uid=4, iid=6, r_ui=0, est=2.7220727559396125, details={'was_impossible': False}),
#  Prediction(uid=4, iid=7, r_ui=0, est=-2.7490424893476644, details={'was_impossible': False}),
#  Prediction(uid=4, iid=8, r_ui=0, est=6.0340150914372375, details={'was_impossible': False}),
#  Prediction(uid=4, iid=9, r_ui=0, est=0.2027338459570801, details={'was_impossible': False}),
#  Prediction(uid=4, iid=10, r_ui=0, est=1.8222056467699685, details={'was_impossible': False}),
#  Prediction(uid=4, iid=11, r_ui=0, est=7.21396461307416, details={'was_impossible': False}),
#  Prediction(uid=4, iid=12, r_ui=0, est=2.972747188933103, details={'was_impossible': False}),
#  Prediction(uid=4, iid=13, r_ui=0, est=6.172488722315299, details={'was_impossible': False}),
#  Prediction(uid=4, iid=14, r_ui=0, est=7.987793252159204, details={'was_impossible': False}),
#  Prediction(uid=4, iid=15, r_ui=0, est=-7.060252229540414, details={'was_impossible': False}),
#  Prediction(uid=4, iid=16, r_ui=0, est=-6.5246593759385005, details={'was_impossible': False}),
#  Prediction(uid=4, iid=17, r_ui=0, est=1.204276097236666, details={'was_impossible': False}),
#  Prediction(uid=4, iid=18, r_ui=0, est=-6.4571737033902075, details={'was_impossible': False}),
#  Prediction(uid=4, iid=19, r_ui=0, est=-3.5788704230403816, details={'was_impossible': False}),
#  Prediction(uid=4, iid=20, r_ui=0, est=-2.041248645602407, details={'was_impossible': False}),
#  Prediction(uid=4, iid=21, r_ui=0, est=5.35155739451994, details={'was_impossible': False}),
#  Prediction(uid=4, iid=22, r_ui=0, est=2.6487638576976282, details={'was_impossible': False}),
#  Prediction(uid=4, iid=23, r_ui=0, est=0.4590774745708992, details={'was_impossible': False}),
#  Prediction(uid=4, iid=24, r_ui=0, est=-0.9101098073216509, details={'was_impossible': False}),
#  Prediction(uid=4, iid=25, r_ui=0, est=2.4006359822056202, details={'was_impossible': False}),
#  Prediction(uid=4, iid=26, r_ui=0, est=2.9567841057359407, details={'was_impossible': False}),
#  Prediction(uid=4, iid=27, r_ui=0, est=3.9129952844553495, details={'was_impossible': False}),
#  Prediction(uid=4, iid=28, r_ui=0, est=6.568457465452117, details={'was_impossible': False}),
#  Prediction(uid=4, iid=29, r_ui=0, est=6.543567858193371, details={'was_impossible': False}),
#  Prediction(uid=4, iid=30, r_ui=0, est=0.5654529162810442, details={'was_impossible': False}),
#  Prediction(uid=4, iid=31, r_ui=0, est=6.584984256626824, details={'was_impossible': False}),
#  Prediction(uid=4, iid=32, r_ui=0, est=3.306790835525607, details={'was_impossible': False}),
#  Prediction(uid=4, iid=33, r_ui=0, est=-0.07102475328727309, details={'was_impossible': False}),
#  Prediction(uid=4, iid=34, r_ui=0, est=7.448706547394625, details={'was_impossible': False}),
#  Prediction(uid=4, iid=35, r_ui=0, est=6.108968612786629, details={'was_impossible': False}),
#  Prediction(uid=4, iid=36, r_ui=0, est=6.518135163462473, details={'was_impossible': False}),
#  Prediction(uid=4, iid=37, r_ui=0, est=-0.6494918208466485, details={'was_impossible': False}),
#  Prediction(uid=4, iid=38, r_ui=0, est=-8.027658480464455, details={'was_impossible': False}),
#  Prediction(uid=4, iid=39, r_ui=0, est=7.045484072834664, details={'was_impossible': False}),
#  Prediction(uid=4, iid=40, r_ui=0, est=2.809221305424873, details={'was_impossible': False}),
#  Prediction(uid=4, iid=41, r_ui=0, est=0.7407611215606718, details={'was_impossible': False}),
#  Prediction(uid=4, iid=42, r_ui=0, est=1.6377084066326153, details={'was_impossible': False}),
#  Prediction(uid=4, iid=43, r_ui=0, est=0.623852794249478, details={'was_impossible': False}),
#  Prediction(uid=4, iid=44, r_ui=0, est=-2.5039303788858187, details={'was_impossible': False}),
#  Prediction(uid=4, iid=45, r_ui=0, est=1.9125155999843302, details={'was_impossible': False}),
#  Prediction(uid=4, iid=46, r_ui=0, est=6.742051024673373, details={'was_impossible': False}),
#  Prediction(uid=4, iid=47, r_ui=0, est=2.0298204770270387, details={'was_impossible': False}),
#  Prediction(uid=4, iid=48, r_ui=0, est=-3.8269100142104104, details={'was_impossible': False}),
#  Prediction(uid=4, iid=49, r_ui=0, est=3.581733165059873, details={'was_impossible': False}),
#  Prediction(uid=4, iid=50, r_ui=0, est=3.462112809557236, details={'was_impossible': False}),
#  Prediction(uid=4, iid=51, r_ui=0, est=2.4174071301084945, details={'was_impossible': False}),
#  Prediction(uid=4, iid=52, r_ui=0, est=3.2611640787812206, details={'was_impossible': False}),
#  Prediction(uid=4, iid=53, r_ui=0, est=1.6195834044843056, details={'was_impossible': False}),
#  Prediction(uid=4, iid=54, r_ui=0, est=4.246768134534073, details={'was_impossible': False}),
#  Prediction(uid=4, iid=55, r_ui=0, est=1.1483784562200658, details={'was_impossible': False}),
#  Prediction(uid=4, iid=56, r_ui=0, est=6.433520968889016, details={'was_impossible': False}),
#  Prediction(uid=4, iid=57, r_ui=0, est=-2.35679736767168, details={'was_impossible': False}),
#  Prediction(uid=4, iid=58, r_ui=0, est=-2.9571486282658004, details={'was_impossible': False}),
#  Prediction(uid=4, iid=59, r_ui=0, est=-0.03219682253435774, details={'was_impossible': False}),
#  Prediction(uid=4, iid=60, r_ui=0, est=0.5242863625907324, details={'was_impossible': False}),
#  Prediction(uid=4, iid=61, r_ui=0, est=0.06941461481342648, details={'was_impossible': False}),
#  Prediction(uid=4, iid=62, r_ui=0, est=-3.5220586214365532, details={'was_impossible': False}),
#  Prediction(uid=4, iid=63, r_ui=0, est=0.7356473253824194, details={'was_impossible': False}),
#  Prediction(uid=4, iid=64, r_ui=0, est=1.0847679534277013, details={'was_impossible': False}),
#  Prediction(uid=4, iid=65, r_ui=0, est=7.724820422718851, details={'was_impossible': False}),
#  Prediction(uid=4, iid=66, r_ui=0, est=0.3034440723119318, details={'was_impossible': False}),
#  Prediction(uid=4, iid=67, r_ui=0, est=-0.3845665621946902, details={'was_impossible': False}),
#  Prediction(uid=4, iid=68, r_ui=0, est=7.10004792410866, details={'was_impossible': False}),
#  Prediction(uid=4, iid=69, r_ui=0, est=2.5009062413708936, details={'was_impossible': False}),
#  Prediction(uid=4, iid=70, r_ui=0, est=1.163295408671136, details={'was_impossible': False}),
#  Prediction(uid=4, iid=71, r_ui=0, est=0.16910102099703073, details={'was_impossible': False}),
#  Prediction(uid=4, iid=72, r_ui=0, est=3.420504252333824, details={'was_impossible': False}),
#  Prediction(uid=4, iid=73, r_ui=0, est=1.5050925420744343, details={'was_impossible': False}),
#  Prediction(uid=4, iid=74, r_ui=0, est=0.8145912331302476, details={'was_impossible': False}),
#  Prediction(uid=4, iid=75, r_ui=0, est=0.038939162895007096, details={'was_impossible': False}),
#  Prediction(uid=4, iid=76, r_ui=0, est=2.4501705804478657, details={'was_impossible': False}),
#  Prediction(uid=4, iid=77, r_ui=0, est=0.7424018941164084, details={'was_impossible': False}),
#  Prediction(uid=4, iid=78, r_ui=0, est=2.8158524871700594, details={'was_impossible': False}),
#  Prediction(uid=4, iid=79, r_ui=0, est=1.5123766075744594, details={'was_impossible': False}),
#  Prediction(uid=4, iid=80, r_ui=0, est=2.11267608486074, details={'was_impossible': False}),
#  Prediction(uid=4, iid=81, r_ui=0, est=3.865568276125723, details={'was_impossible': False}),
#  Prediction(uid=4, iid=82, r_ui=0, est=0.7351483239115499, details={'was_impossible': False}),
#  Prediction(uid=4, iid=83, r_ui=0, est=3.910326706062106, details={'was_impossible': False}),
#  Prediction(uid=4, iid=84, r_ui=0, est=0.05019521593220744, details={'was_impossible': False}),
#  Prediction(uid=4, iid=85, r_ui=0, est=0.6534126747380928, details={'was_impossible': False}),
#  Prediction(uid=4, iid=86, r_ui=0, est=-0.5703958180655642, details={'was_impossible': False}),
#  Prediction(uid=4, iid=87, r_ui=0, est=1.2261548372450939, details={'was_impossible': False}),
#  Prediction(uid=4, iid=88, r_ui=0, est=1.643911431672491, details={'was_impossible': False}),
#  Prediction(uid=4, iid=89, r_ui=0, est=2.849349562378074, details={'was_impossible': False}),
#  Prediction(uid=4, iid=90, r_ui=0, est=0.4187195764511542, details={'was_impossible': False}),
#  Prediction(uid=4, iid=91, r_ui=0, est=2.680106130977409, details={'was_impossible': False}),
#  Prediction(uid=4, iid=92, r_ui=0, est=0.07783909282342849, details={'was_impossible': False}),
#  Prediction(uid=4, iid=93, r_ui=0, est=2.237242950991133, details={'was_impossible': False}),
#  Prediction(uid=4, iid=94, r_ui=0, est=0.5201031281834527, details={'was_impossible': False}),
#  Prediction(uid=4, iid=95, r_ui=0, est=0.2600830040733051, details={'was_impossible': False}),
#  Prediction(uid=4, iid=96, r_ui=0, est=-0.04327663222196798, details={'was_impossible': False}),
#  Prediction(uid=4, iid=97, r_ui=0, est=1.826875208963743, details={'was_impossible': False}),
#  Prediction(uid=4, iid=98, r_ui=0, est=4.442710375295745, details={'was_impossible': False}),
#  Prediction(uid=4, iid=99, r_ui=0, est=0.7077170444415926, details={'was_impossible': False}),
#  Prediction(uid=4, iid=100, r_ui=0, est=2.9846657277575748, details={'was_impossible': False}),
#  Prediction(uid=5, iid=1, r_ui=0, est=8.203264178187837, details={'was_impossible': False}),
#  Prediction(uid=5, iid=2, r_ui=0, est=4.552431822748697, details={'was_impossible': False}),
#  Prediction(uid=5, iid=3, r_ui=0, est=-3.842347165863797, details={'was_impossible': False}),
#  Prediction(uid=5, iid=4, r_ui=0, est=-5.048734430149184, details={'was_impossible': False}),
#  Prediction(uid=5, iid=5, r_ui=0, est=0.7761710556475286, details={'was_impossible': False}),
#  Prediction(uid=5, iid=6, r_ui=0, est=5.016736807840614, details={'was_impossible': False}),
#  Prediction(uid=5, iid=7, r_ui=0, est=6.751685043938276, details={'was_impossible': False}),
#  Prediction(uid=5, iid=8, r_ui=0, est=-0.805314030971097, details={'was_impossible': False}),
#  Prediction(uid=5, iid=9, r_ui=0, est=-0.378247114435768, details={'was_impossible': False}),
#  Prediction(uid=5, iid=10, r_ui=0, est=2.60722302285822, details={'was_impossible': False}),
#  Prediction(uid=5, iid=11, r_ui=0, est=8.050410051055772, details={'was_impossible': False}),
#  Prediction(uid=5, iid=12, r_ui=0, est=6.774341303010678, details={'was_impossible': False}),
#  Prediction(uid=5, iid=13, r_ui=0, est=-3.810160656889277, details={'was_impossible': False}),
#  Prediction(uid=5, iid=14, r_ui=0, est=7.1380914426535895, details={'was_impossible': False}),
#  Prediction(uid=5, iid=15, r_ui=0, est=-2.249437742018473, details={'was_impossible': False}),
#  Prediction(uid=5, iid=16, r_ui=0, est=-9.306336998972144, details={'was_impossible': False}),
#  Prediction(uid=5, iid=17, r_ui=0, est=-0.01950472730170666, details={'was_impossible': False}),
#  Prediction(uid=5, iid=18, r_ui=0, est=-1.3152825590914274, details={'was_impossible': False}),
#  Prediction(uid=5, iid=19, r_ui=0, est=2.526906490116053, details={'was_impossible': False}),
#  Prediction(uid=5, iid=20, r_ui=0, est=4.372826738645, details={'was_impossible': False}),
#  Prediction(uid=5, iid=21, r_ui=0, est=7.999364220688711, details={'was_impossible': False}),
#  Prediction(uid=5, iid=22, r_ui=0, est=6.02854426063143, details={'was_impossible': False}),
#  Prediction(uid=5, iid=23, r_ui=0, est=8.00721323884768, details={'was_impossible': False}),
#  Prediction(uid=5, iid=24, r_ui=0, est=-1.223324107206564, details={'was_impossible': False}),
#  Prediction(uid=5, iid=25, r_ui=0, est=7.566253738672533, details={'was_impossible': False}),
#  Prediction(uid=5, iid=26, r_ui=0, est=2.101774223868638, details={'was_impossible': False}),
#  Prediction(uid=5, iid=27, r_ui=0, est=-0.8386643495053789, details={'was_impossible': False}),
#  Prediction(uid=5, iid=28, r_ui=0, est=5.632015505871145, details={'was_impossible': False}),
#  Prediction(uid=5, iid=29, r_ui=0, est=4.060906693326082, details={'was_impossible': False}),
#  Prediction(uid=5, iid=30, r_ui=0, est=4.506239541347937, details={'was_impossible': False}),
#  Prediction(uid=5, iid=31, r_ui=0, est=7.8420556357827085, details={'was_impossible': False}),
#  Prediction(uid=5, iid=32, r_ui=0, est=-8.667555433068868, details={'was_impossible': False}),
#  Prediction(uid=5, iid=33, r_ui=0, est=6.949396786612294, details={'was_impossible': False}),
#  Prediction(uid=5, iid=34, r_ui=0, est=4.945779978060118, details={'was_impossible': False}),
#  Prediction(uid=5, iid=35, r_ui=0, est=2.5853926445750073, details={'was_impossible': False}),
#  Prediction(uid=5, iid=36, r_ui=0, est=3.1966342139790367, details={'was_impossible': False}),
#  Prediction(uid=5, iid=37, r_ui=0, est=-1.2120433193285056, details={'was_impossible': False}),
#  Prediction(uid=5, iid=38, r_ui=0, est=6.624422065795721, details={'was_impossible': False}),
#  Prediction(uid=5, iid=39, r_ui=0, est=4.519046485962754, details={'was_impossible': False}),
#  Prediction(uid=5, iid=40, r_ui=0, est=2.553560888074858, details={'was_impossible': False}),
#  Prediction(uid=5, iid=41, r_ui=0, est=0.4144756407352065, details={'was_impossible': False}),
#  Prediction(uid=5, iid=42, r_ui=0, est=6.724013658137833, details={'was_impossible': False}),
#  Prediction(uid=5, iid=43, r_ui=0, est=0.23083978107591374, details={'was_impossible': False}),
#  Prediction(uid=5, iid=44, r_ui=0, est=-8.468752628023822, details={'was_impossible': False}),
#  Prediction(uid=5, iid=45, r_ui=0, est=5.148181283106689, details={'was_impossible': False}),
#  Prediction(uid=5, iid=46, r_ui=0, est=6.178269788018228, details={'was_impossible': False}),
#  Prediction(uid=5, iid=47, r_ui=0, est=7.880074525513058, details={'was_impossible': False}),
#  Prediction(uid=5, iid=48, r_ui=0, est=1.4441820891133283, details={'was_impossible': False}),
#  Prediction(uid=5, iid=49, r_ui=0, est=4.554135595571413, details={'was_impossible': False}),
#  Prediction(uid=5, iid=50, r_ui=0, est=0.19956674860401513, details={'was_impossible': False}),
#  Prediction(uid=5, iid=51, r_ui=0, est=4.391490216639655, details={'was_impossible': False}),
#  Prediction(uid=5, iid=52, r_ui=0, est=3.111771602895984, details={'was_impossible': False}),
#  Prediction(uid=5, iid=53, r_ui=0, est=8.686721702587235, details={'was_impossible': False}),
#  Prediction(uid=5, iid=54, r_ui=0, est=7.667559786155462, details={'was_impossible': False}),
#  Prediction(uid=5, iid=55, r_ui=0, est=1.7654753021648266, details={'was_impossible': False}),
#  Prediction(uid=5, iid=56, r_ui=0, est=7.910903374553495, details={'was_impossible': False}),
#  Prediction(uid=5, iid=57, r_ui=0, est=-7.791734838922347, details={'was_impossible': False}),
#  Prediction(uid=5, iid=58, r_ui=0, est=-8.86300082157587, details={'was_impossible': False}),
#  Prediction(uid=5, iid=59, r_ui=0, est=4.823452693601219, details={'was_impossible': False}),
#  Prediction(uid=5, iid=60, r_ui=0, est=0.7942772823205063, details={'was_impossible': False}),
#  Prediction(uid=5, iid=61, r_ui=0, est=7.193303290389105, details={'was_impossible': False}),
#  Prediction(uid=5, iid=62, r_ui=0, est=6.05867696505303, details={'was_impossible': False}),
#  Prediction(uid=5, iid=63, r_ui=0, est=4.659426329497327, details={'was_impossible': False}),
#  Prediction(uid=5, iid=64, r_ui=0, est=-2.0960257638703768, details={'was_impossible': False}),
#  Prediction(uid=5, iid=65, r_ui=0, est=7.205804792571475, details={'was_impossible': False}),
#  Prediction(uid=5, iid=66, r_ui=0, est=4.5073978130780565, details={'was_impossible': False}),
#  Prediction(uid=5, iid=67, r_ui=0, est=6.845176178603406, details={'was_impossible': False}),
#  Prediction(uid=5, iid=68, r_ui=0, est=4.20339932956413, details={'was_impossible': False}),
#  Prediction(uid=5, iid=69, r_ui=0, est=3.0792168461344085, details={'was_impossible': False}),
#  Prediction(uid=5, iid=70, r_ui=0, est=3.8459320243819297, details={'was_impossible': False}),
#  Prediction(uid=5, iid=71, r_ui=0, est=1.7018003073358283, details={'was_impossible': False}),
#  Prediction(uid=5, iid=72, r_ui=0, est=5.510899715227695, details={'was_impossible': False}),
#  Prediction(uid=5, iid=73, r_ui=0, est=3.301647221526235, details={'was_impossible': False}),
#  Prediction(uid=5, iid=74, r_ui=0, est=1.4325732321143, details={'was_impossible': False}),
#  Prediction(uid=5, iid=75, r_ui=0, est=1.3729863823401445, details={'was_impossible': False}),
#  Prediction(uid=5, iid=76, r_ui=0, est=5.191766678219893, details={'was_impossible': False}),
#  Prediction(uid=5, iid=77, r_ui=0, est=4.105445898602106, details={'was_impossible': False}),
#  Prediction(uid=5, iid=78, r_ui=0, est=4.148942881575708, details={'was_impossible': False}),
#  Prediction(uid=5, iid=79, r_ui=0, est=2.533884685896907, details={'was_impossible': False}),
#  Prediction(uid=5, iid=80, r_ui=0, est=3.847919770482794, details={'was_impossible': False}),
#  Prediction(uid=5, iid=81, r_ui=0, est=5.176497372589008, details={'was_impossible': False}),
#  Prediction(uid=5, iid=82, r_ui=0, est=5.776792774352635, details={'was_impossible': False}),
#  Prediction(uid=5, iid=83, r_ui=0, est=1.038238024894357, details={'was_impossible': False}),
#  Prediction(uid=5, iid=84, r_ui=0, est=7.115302027184828, details={'was_impossible': False}),
#  Prediction(uid=5, iid=85, r_ui=0, est=3.8800987546632886, details={'was_impossible': False}),
#  Prediction(uid=5, iid=86, r_ui=0, est=-0.4689136426409679, details={'was_impossible': False}),
#  Prediction(uid=5, iid=87, r_ui=0, est=3.530422746006642, details={'was_impossible': False}),
#  Prediction(uid=5, iid=88, r_ui=0, est=4.653741091133282, details={'was_impossible': False}),
#  Prediction(uid=5, iid=89, r_ui=0, est=2.8930746543345993, details={'was_impossible': False}),
#  Prediction(uid=5, iid=90, r_ui=0, est=2.990033383055967, details={'was_impossible': False}),
#  Prediction(uid=5, iid=91, r_ui=0, est=3.0573662324519733, details={'was_impossible': False}),
#  Prediction(uid=5, iid=92, r_ui=0, est=5.479318175745392, details={'was_impossible': False}),
#  Prediction(uid=5, iid=93, r_ui=0, est=4.26738130094896, details={'was_impossible': False}),
#  Prediction(uid=5, iid=94, r_ui=0, est=5.039553921448526, details={'was_impossible': False}),
#  Prediction(uid=5, iid=95, r_ui=0, est=5.58751459921076, details={'was_impossible': False}),
#  Prediction(uid=5, iid=96, r_ui=0, est=1.6493848948081777, details={'was_impossible': False}),
#  Prediction(uid=5, iid=97, r_ui=0, est=4.040609388604887, details={'was_impossible': False}),
#  Prediction(uid=5, iid=98, r_ui=0, est=6.4214145350246685, details={'was_impossible': False}),
#  Prediction(uid=5, iid=99, r_ui=0, est=1.8109635896994907, details={'was_impossible': False}),
#  Prediction(uid=5, iid=100, r_ui=0, est=1.6762736062516987, details={'was_impossible': False}),
#  Prediction(uid=6, iid=1, r_ui=0, est=-3.2018406304183515, details={'was_impossible': False}),
#  Prediction(uid=6, iid=2, r_ui=0, est=-3.5757490377724683, details={'was_impossible': False}),
#  Prediction(uid=6, iid=3, r_ui=0, est=-4.7850539484191605, details={'was_impossible': False}),
#  Prediction(uid=6, iid=4, r_ui=0, est=-8.3780193890909, details={'was_impossible': False}),
#  Prediction(uid=6, iid=5, r_ui=0, est=-6.913370262240051, details={'was_impossible': False}),
#  Prediction(uid=6, iid=6, r_ui=0, est=-6.128764439276579, details={'was_impossible': False}),
#  Prediction(uid=6, iid=7, r_ui=0, est=-8.389217324410264, details={'was_impossible': False}),
# ...
#  Prediction(uid=9, iid=34, r_ui=0, est=4.481200596390071, details={'was_impossible': False}),
#  Prediction(uid=9, iid=35, r_ui=0, est=3.2904292682446172, details={'was_impossible': False}),
#  Prediction(uid=9, iid=36, r_ui=0, est=1.0602737006044407, details={'was_impossible': False}),
#  Prediction(uid=9, iid=37, r_ui=0, est=-3.1370295678982685, details={'was_impossible': False}),
#  Prediction(uid=9, iid=38, r_ui=0, est=-1.7487978113105707, details={'was_impossible': False}),
#  Prediction(uid=9, iid=39, r_ui=0, est=4.1644774247707135, details={'was_impossible': False}),
#  Prediction(uid=9, iid=40, r_ui=0, est=-4.250722228386967, details={'was_impossible': False}),
#  Prediction(uid=9, iid=41, r_ui=0, est=-1.4585004951234617, details={'was_impossible': False}),
#  Prediction(uid=9, iid=42, r_ui=0, est=1.438180842420497, details={'was_impossible': False}),
#  Prediction(uid=9, iid=43, r_ui=0, est=-5.188509296332127, details={'was_impossible': False}),
#  Prediction(uid=9, iid=44, r_ui=0, est=-6.8322196837183125, details={'was_impossible': False}),
#  Prediction(uid=9, iid=45, r_ui=0, est=1.3180831679932599, details={'was_impossible': False}),
#  Prediction(uid=9, iid=46, r_ui=0, est=4.92395528703506, details={'was_impossible': False}),
#  Prediction(uid=9, iid=47, r_ui=0, est=2.0819362265778785, details={'was_impossible': False}),
#  Prediction(uid=9, iid=48, r_ui=0, est=-0.20522248002058652, details={'was_impossible': False}),
#  Prediction(uid=9, iid=49, r_ui=0, est=0.6428912437470602, details={'was_impossible': False}),
#  Prediction(uid=9, iid=50, r_ui=0, est=-0.08988136450015105, details={'was_impossible': False}),
#  Prediction(uid=9, iid=51, r_ui=0, est=-6.771945925879208, details={'was_impossible': False}),
#  Prediction(uid=9, iid=52, r_ui=0, est=-3.436287032989715, details={'was_impossible': False}),
#  Prediction(uid=9, iid=53, r_ui=0, est=6.196072201013033, details={'was_impossible': False}),
#  Prediction(uid=9, iid=54, r_ui=0, est=1.8386361152945543, details={'was_impossible': False}),
#  Prediction(uid=9, iid=55, r_ui=0, est=3.214343150031603, details={'was_impossible': False}),
#  Prediction(uid=9, iid=56, r_ui=0, est=-0.20207049508557745, details={'was_impossible': False}),
#  Prediction(uid=9, iid=57, r_ui=0, est=-0.4053094217569928, details={'was_impossible': False}),
#  Prediction(uid=9, iid=58, r_ui=0, est=-5.263131567939537, details={'was_impossible': False}),
#  Prediction(uid=9, iid=59, r_ui=0, est=-6.639575069038002, details={'was_impossible': False}),
#  Prediction(uid=9, iid=60, r_ui=0, est=-5.175423087058132, details={'was_impossible': False}),
#  Prediction(uid=9, iid=61, r_ui=0, est=1.2318278620935148, details={'was_impossible': False}),
#  Prediction(uid=9, iid=62, r_ui=0, est=5.3615777121679455, details={'was_impossible': False}),
#  Prediction(uid=9, iid=63, r_ui=0, est=1.2700057553266866, details={'was_impossible': False}),
#  Prediction(uid=9, iid=64, r_ui=0, est=-6.34270419662667, details={'was_impossible': False}),
#  Prediction(uid=9, iid=65, r_ui=0, est=4.721477019228702, details={'was_impossible': False}),
#  Prediction(uid=9, iid=66, r_ui=0, est=4.711348364576691, details={'was_impossible': False}),
#  Prediction(uid=9, iid=67, r_ui=0, est=2.4187338041838045, details={'was_impossible': False}),
#  Prediction(uid=9, iid=68, r_ui=0, est=1.4287769047810324, details={'was_impossible': False}),
#  Prediction(uid=9, iid=69, r_ui=0, est=2.950642878435346, details={'was_impossible': False}),
#  Prediction(uid=9, iid=70, r_ui=0, est=1.4299330698770505, details={'was_impossible': False}),
#  Prediction(uid=9, iid=71, r_ui=0, est=-4.680688376510395, details={'was_impossible': False}),
#  Prediction(uid=9, iid=72, r_ui=0, est=4.078482575998023, details={'was_impossible': False}),
#  Prediction(uid=9, iid=73, r_ui=0, est=-1.9702172714240036, details={'was_impossible': False}),
#  Prediction(uid=9, iid=74, r_ui=0, est=-6.171342158942164, details={'was_impossible': False}),
#  Prediction(uid=9, iid=75, r_ui=0, est=-0.34346053239021435, details={'was_impossible': False}),
#  Prediction(uid=9, iid=76, r_ui=0, est=-0.19282495501773078, details={'was_impossible': False}),
#  Prediction(uid=9, iid=77, r_ui=0, est=0.7294231741900028, details={'was_impossible': False}),
#  Prediction(uid=9, iid=78, r_ui=0, est=-0.25074055442787174, details={'was_impossible': False}),
#  Prediction(uid=9, iid=79, r_ui=0, est=-0.29286111985003305, details={'was_impossible': False}),
#  Prediction(uid=9, iid=80, r_ui=0, est=0.08279222271530942, details={'was_impossible': False}),
#  Prediction(uid=9, iid=81, r_ui=0, est=-0.2655484213270798, details={'was_impossible': False}),
#  Prediction(uid=9, iid=82, r_ui=0, est=-3.109092033228064, details={'was_impossible': False}),
#  Prediction(uid=9, iid=83, r_ui=0, est=-0.21606405461114975, details={'was_impossible': False}),
#  Prediction(uid=9, iid=84, r_ui=0, est=-1.8745601807763033, details={'was_impossible': False}),
#  Prediction(uid=9, iid=85, r_ui=0, est=-1.9188057869209618, details={'was_impossible': False}),
#  Prediction(uid=9, iid=86, r_ui=0, est=-0.28703337776974386, details={'was_impossible': False}),
#  Prediction(uid=9, iid=87, r_ui=0, est=1.5330616285040881, details={'was_impossible': False}),
#  Prediction(uid=9, iid=88, r_ui=0, est=5.518827639402577, details={'was_impossible': False}),
#  Prediction(uid=9, iid=89, r_ui=0, est=2.829956515610708, details={'was_impossible': False}),
#  Prediction(uid=9, iid=90, r_ui=0, est=-2.1846890747810708, details={'was_impossible': False}),
#  Prediction(uid=9, iid=91, r_ui=0, est=4.231795003766153, details={'was_impossible': False}),
#  Prediction(uid=9, iid=92, r_ui=0, est=-0.24544414262524972, details={'was_impossible': False}),
#  Prediction(uid=9, iid=93, r_ui=0, est=4.034342582992934, details={'was_impossible': False}),
#  Prediction(uid=9, iid=94, r_ui=0, est=-0.28582081953327654, details={'was_impossible': False}),
#  Prediction(uid=9, iid=95, r_ui=0, est=-0.268827253405441, details={'was_impossible': False}),
#  Prediction(uid=9, iid=96, r_ui=0, est=-0.23082843317820018, details={'was_impossible': False}),
#  Prediction(uid=9, iid=97, r_ui=0, est=-0.261872204786613, details={'was_impossible': False}),
#  Prediction(uid=9, iid=98, r_ui=0, est=-0.13339340201046615, details={'was_impossible': False}),
#  Prediction(uid=9, iid=99, r_ui=0, est=-0.9997699368558134, details={'was_impossible': False}),
#  Prediction(uid=9, iid=100, r_ui=0, est=-4.808936110360356, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1, r_ui=0, est=3.061114103235817, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2, r_ui=0, est=5.129829351320311, details={'was_impossible': False}),
#  Prediction(uid=10, iid=3, r_ui=0, est=5.136738199755911, details={'was_impossible': False}),
#  Prediction(uid=10, iid=4, r_ui=0, est=3.318547551143318, details={'was_impossible': False}),
#  Prediction(uid=10, iid=5, r_ui=0, est=6.254723300734711, details={'was_impossible': False}),
#  Prediction(uid=10, iid=6, r_ui=0, est=5.128100023039033, details={'was_impossible': False}),
#  Prediction(uid=10, iid=7, r_ui=0, est=2.092611151394199, details={'was_impossible': False}),
#  Prediction(uid=10, iid=8, r_ui=0, est=2.455156231965533, details={'was_impossible': False}),
#  Prediction(uid=10, iid=9, r_ui=0, est=3.0639413936824798, details={'was_impossible': False}),
#  Prediction(uid=10, iid=10, r_ui=0, est=8.00147249566232, details={'was_impossible': False}),
#  Prediction(uid=10, iid=11, r_ui=0, est=5.507912373609104, details={'was_impossible': False}),
#  Prediction(uid=10, iid=12, r_ui=0, est=5.985580952034905, details={'was_impossible': False}),
#  Prediction(uid=10, iid=13, r_ui=0, est=4.325231850610346, details={'was_impossible': False}),
#  Prediction(uid=10, iid=14, r_ui=0, est=5.397703154830513, details={'was_impossible': False}),
#  Prediction(uid=10, iid=15, r_ui=0, est=-4.421561038975699, details={'was_impossible': False}),
#  Prediction(uid=10, iid=16, r_ui=0, est=-0.8807753198178967, details={'was_impossible': False}),
#  Prediction(uid=10, iid=17, r_ui=0, est=-0.3254436638663749, details={'was_impossible': False}),
#  Prediction(uid=10, iid=18, r_ui=0, est=1.581185793009332, details={'was_impossible': False}),
#  Prediction(uid=10, iid=19, r_ui=0, est=0.578040143173832, details={'was_impossible': False}),
#  Prediction(uid=10, iid=20, r_ui=0, est=4.297296817825714, details={'was_impossible': False}),
#  Prediction(uid=10, iid=21, r_ui=0, est=4.591041790964981, details={'was_impossible': False}),
#  Prediction(uid=10, iid=22, r_ui=0, est=5.2331437360441, details={'was_impossible': False}),
#  Prediction(uid=10, iid=23, r_ui=0, est=6.511364786522591, details={'was_impossible': False}),
#  Prediction(uid=10, iid=24, r_ui=0, est=3.0187498811212286, details={'was_impossible': False}),
#  Prediction(uid=10, iid=25, r_ui=0, est=5.980790852894935, details={'was_impossible': False}),
#  Prediction(uid=10, iid=26, r_ui=0, est=6.71757063734817, details={'was_impossible': False}),
#  Prediction(uid=10, iid=27, r_ui=0, est=3.0154493260879907, details={'was_impossible': False}),
#  Prediction(uid=10, iid=28, r_ui=0, est=5.129229069247535, details={'was_impossible': False}),
#  Prediction(uid=10, iid=29, r_ui=0, est=3.560624638976844, details={'was_impossible': False}),
#  Prediction(uid=10, iid=30, r_ui=0, est=5.110983391398093, details={'was_impossible': False}),
#  Prediction(uid=10, iid=31, r_ui=0, est=6.487514069758592, details={'was_impossible': False}),
#  Prediction(uid=10, iid=32, r_ui=0, est=0.13185110896898866, details={'was_impossible': False}),
#  Prediction(uid=10, iid=33, r_ui=0, est=3.1182064728335126, details={'was_impossible': False}),
#  Prediction(uid=10, iid=34, r_ui=0, est=6.413719062677396, details={'was_impossible': False}),
#  Prediction(uid=10, iid=35, r_ui=0, est=9.017724188458114, details={'was_impossible': False}),
#  Prediction(uid=10, iid=36, r_ui=0, est=7.699910130555549, details={'was_impossible': False}),
#  Prediction(uid=10, iid=37, r_ui=0, est=3.021610616543902, details={'was_impossible': False}),
#  Prediction(uid=10, iid=38, r_ui=0, est=6.428154299704113, details={'was_impossible': False}),
#  Prediction(uid=10, iid=39, r_ui=0, est=3.0663543435967946, details={'was_impossible': False}),
#  Prediction(uid=10, iid=40, r_ui=0, est=7.564612462532736, details={'was_impossible': False}),
#  Prediction(uid=10, iid=41, r_ui=0, est=6.507734147684044, details={'was_impossible': False}),
#  Prediction(uid=10, iid=42, r_ui=0, est=5.10002174131488, details={'was_impossible': False}),
#  Prediction(uid=10, iid=43, r_ui=0, est=3.0137407279510278, details={'was_impossible': False}),
#  Prediction(uid=10, iid=44, r_ui=0, est=4.212644085590898, details={'was_impossible': False}),
#  Prediction(uid=10, iid=45, r_ui=0, est=6.6717227125192995, details={'was_impossible': False}),
#  Prediction(uid=10, iid=46, r_ui=0, est=6.697039585886142, details={'was_impossible': False}),
#  Prediction(uid=10, iid=47, r_ui=0, est=4.272066915685682, details={'was_impossible': False}),
#  Prediction(uid=10, iid=48, r_ui=0, est=5.678659018983079, details={'was_impossible': False}),
#  Prediction(uid=10, iid=49, r_ui=0, est=5.398878244096913, details={'was_impossible': False}),
#  Prediction(uid=10, iid=50, r_ui=0, est=4.8339702152354, details={'was_impossible': False}),
#  Prediction(uid=10, iid=51, r_ui=0, est=3.15095365453822, details={'was_impossible': False}),
#  Prediction(uid=10, iid=52, r_ui=0, est=5.111635051505077, details={'was_impossible': False}),
#  Prediction(uid=10, iid=53, r_ui=0, est=6.85276619358747, details={'was_impossible': False}),
#  Prediction(uid=10, iid=54, r_ui=0, est=2.577449410499565, details={'was_impossible': False}),
#  Prediction(uid=10, iid=55, r_ui=0, est=3.118201423152149, details={'was_impossible': False}),
#  Prediction(uid=10, iid=56, r_ui=0, est=3.262983565546034, details={'was_impossible': False}),
#  Prediction(uid=10, iid=57, r_ui=0, est=2.4576896864189255, details={'was_impossible': False}),
#  Prediction(uid=10, iid=58, r_ui=0, est=4.7415907299719695, details={'was_impossible': False}),
#  Prediction(uid=10, iid=59, r_ui=0, est=3.15316768260511, details={'was_impossible': False}),
#  Prediction(uid=10, iid=60, r_ui=0, est=3.016747600641314, details={'was_impossible': False}),
#  Prediction(uid=10, iid=61, r_ui=0, est=4.108950444552288, details={'was_impossible': False}),
#  Prediction(uid=10, iid=62, r_ui=0, est=6.624667331282285, details={'was_impossible': False}),
#  Prediction(uid=10, iid=63, r_ui=0, est=6.694058213915648, details={'was_impossible': False}),
#  Prediction(uid=10, iid=64, r_ui=0, est=3.1271356656769824, details={'was_impossible': False}),
#  Prediction(uid=10, iid=65, r_ui=0, est=4.915326221272438, details={'was_impossible': False}),
#  Prediction(uid=10, iid=66, r_ui=0, est=4.3800634220387185, details={'was_impossible': False}),
#  Prediction(uid=10, iid=67, r_ui=0, est=2.9888400416482512, details={'was_impossible': False}),
#  Prediction(uid=10, iid=68, r_ui=0, est=8.9191472667796, details={'was_impossible': False}),
#  Prediction(uid=10, iid=69, r_ui=0, est=5.23354743760703, details={'was_impossible': False}),
#  Prediction(uid=10, iid=70, r_ui=0, est=3.0750712593999783, details={'was_impossible': False}),
#  Prediction(uid=10, iid=71, r_ui=0, est=1.8861761346113917, details={'was_impossible': False}),
#  Prediction(uid=10, iid=72, r_ui=0, est=3.939647891623189, details={'was_impossible': False}),
#  Prediction(uid=10, iid=73, r_ui=0, est=3.8742471837046817, details={'was_impossible': False}),
#  Prediction(uid=10, iid=74, r_ui=0, est=2.6614451534452392, details={'was_impossible': False}),
#  Prediction(uid=10, iid=75, r_ui=0, est=1.1728593537390857, details={'was_impossible': False}),
#  Prediction(uid=10, iid=76, r_ui=0, est=4.332959606356474, details={'was_impossible': False}),
#  Prediction(uid=10, iid=77, r_ui=0, est=2.5949730708029004, details={'was_impossible': False}),
#  Prediction(uid=10, iid=78, r_ui=0, est=4.150005141366275, details={'was_impossible': False}),
#  Prediction(uid=10, iid=79, r_ui=0, est=2.3421138224488756, details={'was_impossible': False}),
#  Prediction(uid=10, iid=80, r_ui=0, est=3.9683766031115137, details={'was_impossible': False}),
#  Prediction(uid=10, iid=81, r_ui=0, est=3.877989499690835, details={'was_impossible': False}),
#  Prediction(uid=10, iid=82, r_ui=0, est=3.0411886852070875, details={'was_impossible': False}),
#  Prediction(uid=10, iid=83, r_ui=0, est=2.893211638743634, details={'was_impossible': False}),
#  Prediction(uid=10, iid=84, r_ui=0, est=3.3899876850612833, details={'was_impossible': False}),
#  Prediction(uid=10, iid=85, r_ui=0, est=4.528364575080898, details={'was_impossible': False}),
#  Prediction(uid=10, iid=86, r_ui=0, est=2.6910921166942647, details={'was_impossible': False}),
#  Prediction(uid=10, iid=87, r_ui=0, est=3.9130105988553785, details={'was_impossible': False}),
#  Prediction(uid=10, iid=88, r_ui=0, est=3.49869277127033, details={'was_impossible': False}),
#  Prediction(uid=10, iid=89, r_ui=0, est=4.363427613703613, details={'was_impossible': False}),
#  Prediction(uid=10, iid=90, r_ui=0, est=3.6494492062402832, details={'was_impossible': False}),
#  Prediction(uid=10, iid=91, r_ui=0, est=3.1391692459598683, details={'was_impossible': False}),
#  Prediction(uid=10, iid=92, r_ui=0, est=4.424784124079817, details={'was_impossible': False}),
#  Prediction(uid=10, iid=93, r_ui=0, est=4.175148049373427, details={'was_impossible': False}),
#  Prediction(uid=10, iid=94, r_ui=0, est=3.548825192117342, details={'was_impossible': False}),
#  Prediction(uid=10, iid=95, r_ui=0, est=2.928926242956657, details={'was_impossible': False}),
#  Prediction(uid=10, iid=96, r_ui=0, est=3.174769283251108, details={'was_impossible': False}),
#  Prediction(uid=10, iid=97, r_ui=0, est=3.3640104093907826, details={'was_impossible': False}),
#  Prediction(uid=10, iid=98, r_ui=0, est=2.524941898423571, details={'was_impossible': False}),
#  Prediction(uid=10, iid=99, r_ui=0, est=3.0989215745919054, details={'was_impossible': False}),
#  Prediction(uid=10, iid=100, r_ui=0, est=4.209326371719965, details={'was_impossible': False}),
#  ...]

# %%
top_n = get_top_n(pred, 100)

# %%
top_n_1_rank = [(item[0], i+1) for i, item in enumerate(top_n[1])]

# %%
top_n_1_rank
# Out:
# [(29, 1),
#  (2, 2),
#  (61, 3),
#  (14, 4),
#  (54, 5),
#  (68, 6),
#  (27, 7),
#  (69, 8),
#  (35, 9),
#  (36, 10),
#  (50, 11),
#  (8, 12),
#  (47, 13),
#  (62, 14),
#  (53, 15),
#  (28, 16),
#  (59, 17),
#  (49, 18),
#  (31, 19),
#  (89, 20),
#  (22, 21),
#  (26, 22),
#  (56, 23),
#  (65, 24),
#  (46, 25),
#  (48, 26),
#  (72, 27),
#  (76, 28),
#  (93, 29),
#  (91, 30),
#  (66, 31),
#  (83, 32),
#  (88, 33),
#  (34, 34),
#  (98, 35),
#  (87, 36),
#  (80, 37),
#  (92, 38),
#  (81, 39),
#  (39, 40),
#  (100, 41),
#  (11, 42),
#  (96, 43),
#  (84, 44),
#  (71, 45),
#  (95, 46),
#  (32, 47),
#  (25, 48),
#  (23, 49),
#  (85, 50),
#  (55, 51),
#  (40, 52),
#  (10, 53),
#  (77, 54),
#  (70, 55),
#  (60, 56),
#  (99, 57),
#  (94, 58),
#  (73, 59),
#  (90, 60),
#  (19, 61),
#  (97, 62),
#  (86, 63),
#  (79, 64),
#  (75, 65),
#  (12, 66),
#  (63, 67),
#  (74, 68),
#  (45, 69),
#  (13, 70),
#  (52, 71),
#  (15, 72),
#  (17, 73),
#  (5, 74),
#  (30, 75),
#  (16, 76),
#  (82, 77),
#  (1, 78),
#  (41, 79),
#  (38, 80),
#  (4, 81),
#  (6, 82),
#  (51, 83),
#  (42, 84),
#  (9, 85),
#  (64, 86),
#  (21, 87),
#  (43, 88),
#  (67, 89),
#  (33, 90),
#  (44, 91),
#  (37, 92),
#  (57, 93),
#  (78, 94),
#  (58, 95),
#  (3, 96),
#  (18, 97),
#  (20, 98),
#  (7, 99),
#  (24, 100)]

# %%
top_n_1_rank_sorted = sorted(top_n_1_rank, key=lambda x: x[0])

# %%
top_n_1_rank_sorted
# Out:
# [(1, 78),
#  (2, 2),
#  (3, 96),
#  (4, 81),
#  (5, 74),
#  (6, 82),
#  (7, 99),
#  (8, 12),
#  (9, 85),
#  (10, 53),
#  (11, 42),
#  (12, 66),
#  (13, 70),
#  (14, 4),
#  (15, 72),
#  (16, 76),
#  (17, 73),
#  (18, 97),
#  (19, 61),
#  (20, 98),
#  (21, 87),
#  (22, 21),
#  (23, 49),
#  (24, 100),
#  (25, 48),
#  (26, 22),
#  (27, 7),
#  (28, 16),
#  (29, 1),
#  (30, 75),
#  (31, 19),
#  (32, 47),
#  (33, 90),
#  (34, 34),
#  (35, 9),
#  (36, 10),
#  (37, 92),
#  (38, 80),
#  (39, 40),
#  (40, 52),
#  (41, 79),
#  (42, 84),
#  (43, 88),
#  (44, 91),
#  (45, 69),
#  (46, 25),
#  (47, 13),
#  (48, 26),
#  (49, 18),
#  (50, 11),
#  (51, 83),
#  (52, 71),
#  (53, 15),
#  (54, 5),
#  (55, 51),
#  (56, 23),
#  (57, 93),
#  (58, 95),
#  (59, 17),
#  (60, 56),
#  (61, 3),
#  (62, 14),
#  (63, 67),
#  (64, 86),
#  (65, 24),
#  (66, 31),
#  (67, 89),
#  (68, 6),
#  (69, 8),
#  (70, 55),
#  (71, 45),
#  (72, 27),
#  (73, 59),
#  (74, 68),
#  (75, 65),
#  (76, 28),
#  (77, 54),
#  (78, 94),
#  (79, 64),
#  (80, 37),
#  (81, 39),
#  (82, 77),
#  (83, 32),
#  (84, 44),
#  (85, 50),
#  (86, 63),
#  (87, 36),
#  (88, 33),
#  (89, 20),
#  (90, 60),
#  (91, 30),
#  (92, 38),
#  (93, 29),
#  (94, 58),
#  (95, 46),
#  (96, 43),
#  (97, 62),
#  (98, 35),
#  (99, 57),
#  (100, 41)]

# %%
df[df['UID'] == 1].sort_values('JID')
# Out:
#     UID  JID  Rating
# 0     1    1   -7.82
# 1     1    2    8.79
# 2     1    3   -9.66
# 3     1    4   -8.16
# 4     1    5   -7.52
# ..  ...  ...     ...
# 57    1   69    5.68
# 58    1   70   -4.81
# 59    1   78   -9.42
# 60    1   82   -7.72
# 61    1   97   -5.63
#
# [62 rows x 3 columns]

# %%
sorted([(item, i+1) for i, item in enumerate(top_n[1])], key=lambda x: x[0][0])
# Out:
# [((1, -7.5869082363041125), 78),
#  ((2, 8.382193195823827), 2),
#  ((3, -9.501438022434291), 96),
#  ((4, -8.181289711605473), 81),
#  ((5, -7.368125640525279), 74),
#  ((6, -8.202881206876636), 82),
#  ((7, -9.65915638100404), 99),
#  ((8, 3.849424515470821), 12),
#  ((9, -8.848593832230408), 85),
#  ((10, -4.705652247369905), 53),
#  ((11, -3.2292266832839562), 42),
#  ((12, -6.409789109265508), 66),
#  ((13, -7.024773392560044), 70),
#  ((14, 8.1204072535496), 4),
#  ((15, -7.101641366968603), 72),
#  ((16, -7.505614725835342), 76),
#  ((17, -7.267275025077714), 73),
#  ((18, -9.555147154617341), 97),
#  ((19, -5.428870587262538), 61),
#  ((20, -9.642741695534955), 98),
#  ((21, -8.909191928719059), 87),
#  ((22, 1.3049553917546022), 21),
#  ((23, -4.373984702925547), 49),
#  ((24, -9.758089291918346), 100),
#  ((25, -3.8801026283200417), 48),
#  ((26, 1.0482150086619777), 22),
#  ((27, 7.591823178271042), 7),
#  ((28, 2.6997348442810334), 16),
#  ((29, 8.898706568225885), 1),
#  ((30, -7.400254999612057), 75),
#  ((31, 1.7459330866314655), 19),
#  ((32, -3.743402438630424), 47),
#  ((33, -8.998199372589479), 90),
#  ((34, -2.317229228569088), 34),
#  ((35, 4.970112179440567), 9),
#  ((36, 4.86158563160358), 10),
#  ((37, -9.048827095999183), 92),
#  ((38, -8.141232485431471), 80),
#  ((39, -2.854284176643082), 40),
#  ((40, -4.666990232664525), 52),
#  ((41, -8.04916114805949), 79),
#  ((42, -8.728721220759008), 84),
#  ((43, -8.935575869804282), 88),
#  ((44, -9.032891167734999), 91),
#  ((45, -6.9593830631555775), 69),
#  ((46, 0.10043949862813584), 25),
#  ((47, 3.630214515267255), 13),
#  ((48, -0.06312867996442029), 26),
#  ((49, 2.080797617512883), 18),
#  ((50, 4.107928045793073), 11),
#  ((51, -8.560118873517844), 83),
#  ((52, -7.037171407583987), 71),
#  ((53, 3.2300444576905014), 15),
#  ((54, 8.068271189344168), 5),
#  ((55, -4.499081039903628), 51),
#  ((56, 0.8977871589774014), 23),
#  ((57, -9.063565574828845), 93),
#  ((58, -9.391803416754332), 95),
#  ((59, 2.463207118025733), 17),
#  ((60, -4.86787295539153), 56),
#  ((61, 8.281268687995368), 3),
#  ((62, 3.5087029474422775), 14),
#  ((63, -6.682795742833007), 67),
#  ((64, -8.87764742864266), 86),
#  ((65, 0.17232500326865785), 24),
#  ((66, -1.2486265981571738), 31),
#  ((67, -8.970579878637981), 89),
#  ((68, 7.977295856565026), 6),
#  ((69, 5.484545211601245), 8),
#  ((70, -4.781364863570172), 55),
#  ((71, -3.7206345552677247), 45),
#  ((72, -0.11054122026192859), 27),
#  ((73, -5.085393744635648), 59),
#  ((74, -6.82303478925918), 68),
#  ((75, -5.982477019911048), 65),
#  ((76, -0.45614108974798107), 28),
#  ((77, -4.767463075999157), 54),
#  ((78, -9.17969428193028), 94),
#  ((79, -5.6770538537454645), 64),
#  ((80, -2.581810188785891), 37),
#  ((81, -2.849942178550789), 39),
#  ((82, -7.565451469022632), 77),
#  ((83, -1.7117865613582528), 32),
#  ((84, -3.7129663504355657), 44),
#  ((85, -4.386430664395008), 50),
#  ((86, -5.514841568078301), 63),
#  ((87, -2.478438725330892), 36),
#  ((88, -1.9647480309300027), 33),
#  ((89, 1.739821787808388), 20),
#  ((90, -5.165312160452079), 60),
#  ((91, -0.9954757330525609), 30),
#  ((92, -2.650232453737493), 38),
#  ((93, -0.7440896410571576), 29),
#  ((94, -5.037513973817473), 58),
#  ((95, -3.725242703458887), 46),
#  ((96, -3.580553662598738), 43),
#  ((97, -5.4905935444000775), 62),
#  ((98, -2.405267400506938), 35),
#  ((99, -5.027696336020645), 57),
#  ((100, -3.0181543525420924), 41)]

# %%
test = pd.read_csv(r'..\data\recsys-in-practice\test_joke_df_nofactrating.csv', index_col=0)
test.head(5)
# Out:
#                  UID  JID
# InteractionID
# 0              11228   39
# 1              21724   85
# 2              16782   56
# 3              12105   42
# 4              14427    2

# %%
test['Rating'] = test[['UID', 'JID']].apply(lambda x: algo.predict(x[0], x[1], verbose=False).est,
                                                      axis = 1)

# %%
# вид набора данных, который должен быть отправлен для тестирования
test['Rating'].to_frame().head(5)
# Out:
#                  Rating
# InteractionID
# 0              3.042851
# 1             -7.039993
# 2             -0.331728
# 3              6.796138
# 4              5.779301

# %%
# формирование файла для отправки в Kaggle
test['Rating'].to_frame().to_csv('baseline_svd_tuning_best_4.02408.csv')

# %%
sns.distplot(test['Rating'])
# Out:
# C:\Temp\ipykernel_10460\3093547129.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(test['Rating'])
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %%
solution = pd.read_csv('baseline_svd_tuning_best_4.02408.csv')

# %%
def correct(x):
    x2 = round(np.abs(x))
    r = 0
    if x2 == 0: r = 1
    if x2 == 1: r = 1
    if x2 == 2: r = 1
    elif x2 == 3: r = 0.9
    elif x2 == 4: r = 0.8
    elif x2 == 5: r = 0.7
    elif x2 == 6: r = 0.6
    elif x2 == 7: r = 0.5
    elif x2 == 8: r = 0.4
    elif x2 == 9: r = 0.3
    return x + r * np.sign(x)

# %%
test['Rating'] = solution['Rating'].apply(correct)
test
# Out:
#                  UID  JID    Rating
# InteractionID
# 0              11228   39  3.942851
# 1              21724   85 -7.539993
# 2              16782   56 -1.331728
# 3              12105   42  7.296138
# 4              14427    2  6.379301
# ...              ...  ...       ...
# 362086          3085   66 -1.540293
# 362087         13765   31  3.404859
# 362088         10341   29  5.552438
# 362089          3553    8 -4.613623
# 362090          1199   67 -2.506481
#
# [362091 rows x 3 columns]

# %%
test['Rating'].to_frame().head(5)
# Out:
#                  Rating
# InteractionID
# 0              3.942851
# 1             -7.539993
# 2             -1.331728
# 3              7.296138
# 4              6.379301

# %%
test['Rating'].to_frame().to_csv('solution.csv')

# %%
sns.distplot(df['Rating'])
sns.distplot(solution['Rating'])
# Out:
# C:\Temp\ipykernel_10460\1495490845.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Rating'])
# C:\Temp\ipykernel_10460\1495490845.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(solution['Rating'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\envs\torchvision2\lib\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\envs\torchvision2\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\envs\torchvision2\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Rating2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [34], in <cell line: 3>()
#       1 sns.distplot(df['Rating'])
#       2 sns.distplot(solution['Rating'])
# ----> 3 sns.distplot(solution['Rating2'])
#
# File C:\ProgramData\Anaconda3\envs\torchvision2\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File C:\ProgramData\Anaconda3\envs\torchvision2\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 'Rating2'

# %%
algo.predict(11228, 39, verbose=False)
# Out:
# Prediction(uid=11228, iid=39, r_ui=None, est=3.0428512748956713, details={'was_impossible': False})

# %%
algo.estimate(u=11228, i=39)
# Out:
# -1.434611076709447

# %%
algo.bi[:10], algo.bu[:10]
# Out:
# (array([ 0.31033319, -0.38314812, -0.08525166, -1.24617922, -0.24116796,
#          0.29776527, -0.65546489, -0.85163282, -0.70304173,  0.45724906]),
#  array([-1.68376186,  0.5438339 ,  2.02106013,  0.51446725,  0.67149867,
#         -2.30392862,  1.19760621, -1.23214924, -0.82893065,  1.30338976]))

# %%
algo.pu.shape, algo.qi.shape
# Out:
# ((24983, 512), (100, 512))

# %%
algo.pu[:10, :10]
# Out:
# array([[-2.86540909e-01,  1.04682178e-01, -4.40082676e-02,
#         -2.78974646e-01,  1.55769587e-01,  2.33472301e-01,
#         -2.90557384e-01,  1.25727306e-01, -6.00099210e-02,
#          4.33443298e-01],
#        [ 1.00130047e-01,  1.11911840e-02,  1.80694479e-01,
#          5.76512181e-02, -5.06843480e-01, -4.76710669e-03,
#         -2.03006176e-01,  4.81218886e-01, -1.14859621e-01,
#         -7.97198521e-01],
#        [-1.04715753e-02,  1.73412797e-01, -1.86219941e-01,
#          2.50241689e-02,  2.61903041e-02,  1.22564945e-01,
#         -2.08922939e-01,  4.23749869e-02,  1.12724775e-02,
#          1.93108593e-01],
#        [ 7.39884797e-02, -3.54489662e-01,  2.72771052e-01,
#         -1.08249569e-01,  1.12400044e-01,  1.28777192e-01,
#         -3.50327757e-01, -5.84792905e-03, -3.83755907e-01,
#          1.19397693e-01],
#        [ 5.46110149e-02,  2.10468622e-01,  8.70760855e-02,
#         -2.20986971e-01, -1.72452039e-01,  5.37873306e-02,
#         -1.55922221e-01, -2.53234396e-01, -3.04765883e-01,
#          4.07663170e-01],
#        [ 4.11506948e-01, -2.45283326e-01,  4.46240961e-01,
#         -1.35429842e-01,  2.30552677e-01, -4.94699746e-02,
#          6.48857282e-02, -1.65249857e-01, -1.69058902e-01,
#          8.77603614e-04],
#        [-5.31997962e-01,  6.83102889e-03,  1.25909499e-01,
#          3.85726819e-01, -8.03746051e-02,  1.77200265e-02,
#         -2.44210961e-01,  1.08663557e-01, -7.50301582e-04,
#          1.76287397e-01],
#        [ 8.79281155e-01,  2.48835977e-01,  1.22493469e-01,
#          9.78665007e-02,  9.72310840e-02, -2.86190917e-01,
#         -3.82625585e-02, -3.13838555e-01,  2.52450493e-02,
#         -7.89215889e-02],
#        [-1.13488184e-01,  5.21220043e-01, -3.40082584e-02,
#         -2.10814109e-01, -1.28972361e-01, -2.15244927e-01,
#         -5.06275660e-02, -1.21853542e-01, -1.68397102e-01,
#          2.22419544e-01],
#        [-1.35300047e-01, -6.12526994e-02,  1.10776734e-01,
#          1.10683110e-01, -1.15111018e-01,  8.03468074e-02,
#         -6.69324705e-02, -8.70938985e-02, -2.56105214e-02,
#          3.85664814e-03]])

# %%
algo.qi[:10, :10]
# Out:
# array([[ 1.42092474e-01,  1.61276209e-01, -8.58432291e-02,
#          1.40841410e-01,  1.15382942e-01,  2.60779834e-01,
#         -2.67846035e-01, -1.28507405e-01, -3.11427432e-01,
#          2.61877555e-01],
#        [-2.06023366e-01, -3.68222652e-01, -2.53905255e-01,
#          1.28672021e-01,  5.88190220e-01,  1.17129196e-01,
#         -5.86125184e-01,  3.78145352e-02, -6.39655282e-01,
#         -1.37629416e-01],
#        [ 1.48906944e-01,  1.16978034e-01,  8.68937448e-02,
#         -2.57897090e-01, -2.50732684e-01, -2.47545169e-01,
#          2.18251764e-01, -3.54962425e-02, -1.69172808e-01,
#         -2.03568401e-01],
#        [ 2.53485234e-02,  1.69686558e-01, -8.10586376e-02,
#         -3.83575563e-01,  8.83551505e-02, -1.08314318e-01,
#         -4.81364792e-02, -1.27589511e-01, -4.72955745e-01,
#         -2.93192461e-01],
#        [ 2.01929898e-01, -4.43162738e-01, -1.94423166e-01,
#          4.80267173e-01,  1.20569405e-01, -3.75769156e-01,
#          1.02972785e-01, -2.15261316e-01, -1.43594167e-01,
#          1.68540398e-01],
#        [ 3.20025330e-01,  1.56344428e-02, -1.40548469e-01,
#         -3.53019637e-01,  2.98427812e-01,  2.68360992e-01,
#          2.49847987e-01, -2.44461697e-01,  2.88265512e-01,
#         -2.38732319e-02],
#        [-4.44312758e-02,  3.09345913e-01, -6.42321961e-01,
#          1.34926155e-01, -4.97855711e-04, -2.50453780e-02,
#         -2.81530674e-01,  2.39797698e-01,  1.96248565e-01,
#         -2.28037043e-02],
#        [-9.03280556e-02, -1.46274308e-01,  1.66799159e-01,
#         -6.54665927e-02,  2.28582323e-01,  4.63490943e-01,
#         -7.04157665e-02,  1.10186736e-01,  2.75432725e-01,
#          4.01904648e-01],
#        [ 3.56873925e-01, -2.07872839e-02,  2.58328497e-01,
#         -3.03465393e-01, -3.68540248e-01,  7.78435462e-02,
#          2.24130561e-01, -8.53989668e-03,  2.48121019e-01,
#          3.16616199e-01],
#        [ 2.54352902e-02, -3.67934871e-01, -2.28877685e-03,
#          1.12241047e-01, -3.68927859e-02,  1.15273271e-02,
#         -3.09169699e-03,  2.93659887e-01, -1.17663897e-01,
#         -2.35589608e-01]])

# %%
#r_ui = q_i.T * p_u

# %%
joke_df = pd.DataFrame(algo.qi, index=np.arange(1, 101), columns=[f'joke_feature_{i}' for i in np.arange(1, 513)])
joke_df
# Out:
#      joke_feature_1  joke_feature_2  joke_feature_3  joke_feature_4  \
# 1          0.142092        0.161276       -0.085843        0.140841
# 2         -0.206023       -0.368223       -0.253905        0.128672
# 3          0.148907        0.116978        0.086894       -0.257897
# 4          0.025349        0.169687       -0.081059       -0.383576
# 5          0.201930       -0.443163       -0.194423        0.480267
# ..              ...             ...             ...             ...
# 96         0.038310       -0.320784       -0.398948       -0.105061
# 97        -0.077509       -0.022602        0.060548        0.197736
# 98         0.075268        0.170505        0.047921       -0.148171
# 99        -0.205066        0.158408        0.120122        0.010672
# 100       -0.156539        0.334500        0.287737       -0.025970
#
#      joke_feature_5  joke_feature_6  joke_feature_7  joke_feature_8  \
# 1          0.115383        0.260780       -0.267846       -0.128507
# 2          0.588190        0.117129       -0.586125        0.037815
# 3         -0.250733       -0.247545        0.218252       -0.035496
# 4          0.088355       -0.108314       -0.048136       -0.127590
# 5          0.120569       -0.375769        0.102973       -0.215261
# ..              ...             ...             ...             ...
# 96        -0.323993        0.033493       -0.199585       -0.163368
# 97         0.184115        0.081155       -0.053317        0.247596
# 98        -0.248123        0.540658        0.578694       -0.504111
# 99         0.282904       -0.064747       -0.141366       -0.141666
# 100        0.019847        0.383873        0.056068       -0.284088
#
#      joke_feature_9  joke_feature_10  ...  joke_feature_503  joke_feature_504  \
# 1         -0.311427         0.261878  ...         -0.086997          0.642238
# 2         -0.639655        -0.137629  ...         -0.178951         -0.149339
# 3         -0.169173        -0.203568  ...          0.171719          0.440527
# 4         -0.472956        -0.293192  ...          0.275108          0.134429
# 5         -0.143594         0.168540  ...          0.055489          0.004459
# ..              ...              ...  ...               ...               ...
# 96         0.033929        -0.117046  ...         -0.073269         -0.095354
# 97         0.491517         0.059379  ...          0.053112          0.233028
# 98         0.269925        -0.383362  ...          0.389070          0.249536
# 99        -0.273635         0.256025  ...         -0.130165         -0.105244
# 100        0.260577        -0.488830  ...         -0.203204         -0.256741
#
#      joke_feature_505  joke_feature_506  joke_feature_507  joke_feature_508  \
# 1            0.129015          0.137358          0.031935         -0.369892
# 2           -0.510708          0.149664          0.414782         -0.469664
# 3            0.922526          0.039237          0.331373          0.179839
# 4            0.122094         -0.077651          0.137801          0.119666
# 5            0.147334         -0.039287         -0.045829         -0.257551
# ..                ...               ...               ...               ...
# 96          -0.421509          0.094863          0.302751         -0.086174
# 97          -0.527038         -0.171914         -0.148308         -0.289133
# 98           0.481943          0.394409         -0.178223          0.342982
# 99           0.359539         -0.736978          0.240493         -0.314474
# 100          0.179778         -0.421614          0.744649          0.459115
#
#      joke_feature_509  joke_feature_510  joke_feature_511  joke_feature_512
# 1           -0.098020          0.174669          0.188299         -0.188564
# 2           -0.292359          0.120598          0.159565         -0.283802
# 3           -0.060934          0.573456         -0.198039          0.014901
# 4           -0.254773          0.038136          0.047085         -0.437655
# 5           -0.128635         -0.047791         -0.077637         -0.079604
# ..                ...               ...               ...               ...
# 96           0.244086         -0.298745         -0.548658          0.063677
# 97           0.408143         -0.086640          0.042957          0.294954
# 98           0.091326          0.447302          0.327257         -0.482502
# 99           0.229752         -0.344169          0.072157          0.038428
# 100          0.528252         -0.231783          0.002181          0.021047
#
# [100 rows x 512 columns]

# %%
joke_df.to_csv('joke_df_features_svd_best_4.02408.csv', index=False)

# %%
user_df = pd.DataFrame(algo.pu, index=np.arange(1, 24984), columns=[f'user_feature_{i}' for i in np.arange(1, 513)])
user_df
# Out:
#        user_feature_1  user_feature_2  user_feature_3  user_feature_4  \
# 1           -0.286541        0.104682       -0.044008       -0.278975
# 2            0.100130        0.011191        0.180694        0.057651
# 3           -0.010472        0.173413       -0.186220        0.025024
# 4            0.073988       -0.354490        0.272771       -0.108250
# 5            0.054611        0.210469        0.087076       -0.220987
# ...               ...             ...             ...             ...
# 24979       -0.204535        0.201597        0.330617       -0.694725
# 24980       -0.123892        0.542251        0.094026        0.517962
# 24981        0.266890        0.191195       -0.456191       -0.030366
# 24982        0.191638        0.176592       -0.300390       -0.022184
# 24983       -0.050989       -0.373188       -0.339595        0.213095
#
#        user_feature_5  user_feature_6  user_feature_7  user_feature_8  \
# 1            0.155770        0.233472       -0.290557        0.125727
# 2           -0.506843       -0.004767       -0.203006        0.481219
# 3            0.026190        0.122565       -0.208923        0.042375
# 4            0.112400        0.128777       -0.350328       -0.005848
# 5           -0.172452        0.053787       -0.155922       -0.253234
# ...               ...             ...             ...             ...
# 24979        0.001912        0.267243       -0.305405        0.056835
# 24980       -0.226276        0.479779        0.424285        0.023049
# 24981       -0.217968       -0.054737        0.234432        0.257438
# 24982       -0.241778       -0.259135       -0.072225        0.680874
# 24983       -0.022491        0.268045        0.061874        0.273121
#
#        user_feature_9  user_feature_10  ...  user_feature_503  \
# 1           -0.060010         0.433443  ...          0.187660
# 2           -0.114860        -0.797199  ...          0.103556
# 3            0.011272         0.193109  ...          0.267017
# 4           -0.383756         0.119398  ...          0.438087
# 5           -0.304766         0.407663  ...         -0.192879
# ...               ...              ...  ...               ...
# 24979       -0.128771         0.093763  ...          0.095866
# 24980        0.123218        -0.272921  ...          0.125407
# 24981        0.104117         0.123815  ...          0.167595
# 24982       -0.148201        -0.854220  ...         -0.270552
# 24983       -0.242611        -0.101929  ...         -0.184656
#
#        user_feature_504  user_feature_505  user_feature_506  user_feature_507  \
# 1             -0.748804          0.184476          0.437187          0.107889
# 2              0.374058         -0.003225          0.082901          0.224330
# 3             -0.108724         -0.008937          0.367659          0.119576
# 4             -0.234654          0.201837         -0.028444          0.190255
# 5              0.172597          0.106194          0.043944         -0.095593
# ...                 ...               ...               ...               ...
# 24979          0.020649         -0.717700         -0.003190          0.958830
# 24980         -0.332979          0.596783          0.098348          0.029290
# 24981          0.290841          0.253620          0.184360          0.042521
# 24982          0.028185         -0.092904          0.351073          0.032425
# 24983         -0.459158         -0.115747         -0.318918          0.002870
#
#        user_feature_508  user_feature_509  user_feature_510  user_feature_511  \
# 1             -0.386573         -0.215301          0.357517         -0.005902
# 2              0.023630          0.253504          0.111037          0.059824
# 3              0.035629         -0.114915          0.355590         -0.436345
# 4              0.083467         -0.268704          0.154939         -0.172352
# 5             -0.311244          0.158506         -0.330597         -0.037131
# ...                 ...               ...               ...               ...
# 24979         -0.228004         -0.187103         -0.086593          0.137313
# 24980          0.408383         -0.144344          1.065045          1.042894
# 24981          0.419433         -0.132864         -0.022923          0.537218
# 24982         -0.193008          0.072129         -0.150102          0.583104
# 24983          0.152029          0.184877          0.042701          0.117431
#
#        user_feature_512
# 1              0.169848
# 2             -0.254858
# 3             -0.123203
# 4              0.211647
# 5              0.581990
# ...                 ...
# 24979          0.452712
# 24980         -0.214078
# 24981         -0.084455
# 24982         -0.078574
# 24983         -0.114076
#
# [24983 rows x 512 columns]

# %%
user_df.to_csv('user_df_features_svd_best_4.02408.csv', index=False)

# %%
df_features = df.merge(user_df, left_on='UID', right_index=True).merge(joke_df, left_on='JID', right_index=True)
df_features
# Out:
#            UID  JID  Rating  user_feature_1  user_feature_2  user_feature_3  \
# 0            1    1   -7.82       -0.286541        0.104682       -0.044008
# 62           2    1    4.08        0.100130        0.011191        0.180694
# 226          5    1    8.50        0.054611        0.210469        0.087076
# 578         10    1    3.01       -0.135300       -0.061253        0.110777
# 643         11    1   -2.91       -0.093135        0.120376       -0.114751
# ...        ...  ...     ...             ...             ...             ...
# 1447088  24959   75   -2.38        0.220270       -0.027020        0.103505
# 1447277  24963   75   -6.80        0.080809       -0.434816        0.825751
# 1447442  24966   75    2.91        0.168680        0.106525        0.014566
# 1447808  24972   75   -3.98       -0.138008        0.295111       -0.097380
# 1448155  24979   75    9.13       -0.204535        0.201597        0.330617
#
#          user_feature_4  user_feature_5  user_feature_6  user_feature_7  ...  \
# 0             -0.278975        0.155770        0.233472       -0.290557  ...
# 62             0.057651       -0.506843       -0.004767       -0.203006  ...
# 226           -0.220987       -0.172452        0.053787       -0.155922  ...
# 578            0.110683       -0.115111        0.080347       -0.066932  ...
# 643            0.081270       -0.131483       -0.265416        0.113452  ...
# ...                 ...             ...             ...             ...  ...
# 1447088       -0.254154        0.112541        0.153324       -0.082309  ...
# 1447277        0.219109        0.202813       -0.108498       -0.009693  ...
# 1447442       -0.152262       -0.102457        0.026825       -0.021076  ...
# 1447808        0.101352       -0.301799        0.262305        0.093549  ...
# 1448155       -0.694725        0.001912        0.267243       -0.305405  ...
#
#          joke_feature_503  joke_feature_504  joke_feature_505  \
# 0               -0.086997          0.642238          0.129015
# 62              -0.086997          0.642238          0.129015
# 226             -0.086997          0.642238          0.129015
# 578             -0.086997          0.642238          0.129015
# 643             -0.086997          0.642238          0.129015
# ...                   ...               ...               ...
# 1447088          0.028936         -0.513462          0.056351
# 1447277          0.028936         -0.513462          0.056351
# 1447442          0.028936         -0.513462          0.056351
# 1447808          0.028936         -0.513462          0.056351
# 1448155          0.028936         -0.513462          0.056351
#
#          joke_feature_506  joke_feature_507  joke_feature_508  \
# 0                0.137358          0.031935         -0.369892
# 62               0.137358          0.031935         -0.369892
# 226              0.137358          0.031935         -0.369892
# 578              0.137358          0.031935         -0.369892
# 643              0.137358          0.031935         -0.369892
# ...                   ...               ...               ...
# 1447088          0.293027          0.426814         -0.437927
# 1447277          0.293027          0.426814         -0.437927
# 1447442          0.293027          0.426814         -0.437927
# 1447808          0.293027          0.426814         -0.437927
# 1448155          0.293027          0.426814         -0.437927
#
#          joke_feature_509  joke_feature_510  joke_feature_511  \
# 0               -0.098020          0.174669          0.188299
# 62              -0.098020          0.174669          0.188299
# 226             -0.098020          0.174669          0.188299
# 578             -0.098020          0.174669          0.188299
# 643             -0.098020          0.174669          0.188299
# ...                   ...               ...               ...
# 1447088         -0.103398         -0.297193         -0.245112
# 1447277         -0.103398         -0.297193         -0.245112
# 1447442         -0.103398         -0.297193         -0.245112
# 1447808         -0.103398         -0.297193         -0.245112
# 1448155         -0.103398         -0.297193         -0.245112
#
#          joke_feature_512
# 0               -0.188564
# 62              -0.188564
# 226             -0.188564
# 578             -0.188564
# 643             -0.188564
# ...                   ...
# 1447088         -0.058789
# 1447277         -0.058789
# 1447442         -0.058789
# 1447808         -0.058789
# 1448155         -0.058789
#
# [1448364 rows x 1027 columns]

# %%
df_features.to_csv('df_features_svd_best_4.02408.csv', index=False)
# Out:
# KeyboardInterrupt

# %%
df_test_features = test.merge(user_df, left_on='UID', right_index=True).merge(joke_df, left_on='JID', right_index=True)
df_test_features

# %%
df_test_features.to_csv('df_test_features_svd_best_4.02408.csv')
